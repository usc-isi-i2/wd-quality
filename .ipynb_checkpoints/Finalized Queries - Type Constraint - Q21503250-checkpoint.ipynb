# %% [markdown]
# # Type Constraint (Domain)

# %%
# !kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.properties.tsv.gz \
    ../../gdrive-kgtk-dump-2020-12-07/qualifiers.properties.tsv.gz \
    --match "p: (nodeProp1)-[nodePropEdge:P2302]->(nodeabc{wikidatatype:wikidatatype}), q: (nodePropEdge1)-[nodePropEdgeProps]->(val)" \
    --where 'nodePropEdge.id = nodePropEdge1 and nodeabc = "Q21503250"' \
    --return 'nodePropEdge.id as id, nodeProp1 as node1, nodePropEdgeProps.label as label, val as node2, wikidatatype as `node2;wikidatatype`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints_all1.tsv \
    --graph-cache ~/sqlite3_caches/temp156.sqlite3.db
# Out:
# [2021-03-08 12:08:21 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id" "_aLias.id", graph_1_c1."node1" "_aLias.node1", graph_2_c2."label" "_aLias.label", graph_2_c2."node2" "_aLias.node2", graph_1_c1."node2;wikidatatype" "_aLias.node2;wikidatatype"
#      FROM graph_1 AS graph_1_c1, graph_2 AS graph_2_c2
#      WHERE graph_1_c1."label"=?
#      AND graph_1_c1."node2;wikidatatype"=graph_1_c1."node2;wikidatatype"
#      AND ((graph_1_c1."id" = graph_2_c2."node1") AND (graph_1_c1."node2" = ?))
#   PARAS: ['P2302', 'Q21503250']
# ---------------------------------------------

# %%
# !kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.tsv.gz \
#     ../../gdrive-kgtk-dump-2020-12-07/claims.properties.tsv.gz \
#     --match "t: (node1)-[label1]->(node2), p: (nodeProp1)-[:P2302]->(:Q21503250)" \
#     --where 'label1.label = nodeProp1' \
#     --return 'label1.id as id, node1, label1.label as label, node2' \
#     -o ../../constraintsOP/typeConstraint/claims_truncated2.tsv \
#     --graph-cache ~/sqlite3_caches/temp10.sqlite3.db
# Out:
# [2021-03-06 07:57:51 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id" "_aLias.id", graph_1_c1."node1", graph_1_c1."label" "_aLias.label", graph_1_c1."node2"
#      FROM graph_1 AS graph_1_c1, graph_2 AS graph_2_c2
#      WHERE graph_2_c2."label"=?
#      AND graph_2_c2."node2"=?
#      AND (graph_1_c1."label" = graph_2_c2."node1")
#   PARAS: ['P2302', 'Q21503250']
# ---------------------------------------------
# ^C

# %%
# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match '(node1)-[label:P2309]->(node2)' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints_relation.tsv

# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match '(node1)-[label:P2316]->(node2)' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug.tsv

# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match '(node1)-[label:P2308]->(node2)' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints_classes.tsv

# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match '(node1)-[label:P2303]->(node2)' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints_exceptions.tsv
# Out:
# [2021-03-04 15:47:23 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_49 AS graph_49_c1
#      WHERE graph_49_c1."label"=?
#   PARAS: ['P2309']
# ---------------------------------------------
# [2021-03-04 15:47:23 sqlstore]: CREATE INDEX on table graph_49 column label ...
# [2021-03-04 15:47:23 sqlstore]: ANALYZE INDEX on table graph_49 column label ...
# [2021-03-04 15:47:24 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_49 AS graph_49_c1
#      WHERE graph_49_c1."label"=?
#   PARAS: ['P2316']
# ---------------------------------------------
# [2021-03-04 15:47:25 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_49 AS graph_49_c1
#      WHERE graph_49_c1."label"=?
#   PARAS: ['P2308']
# ---------------------------------------------
# [2021-03-04 15:47:25 query]: SQL Translation:
# ---------------------------------------------
#   SELECT *
#      FROM graph_49 AS graph_49_c1
#      WHERE graph_49_c1."label"=?
#   PARAS: ['P2303']
# ---------------------------------------------

# %% [markdown]
# ## Test Constraints Queries

# %%
# !printf "id\tnode1\tlabel\tnode2\nxxxx\tQ106810\tderived\tQ135031\n" \
    > ../../constraintsOP/testConstraints/derivedP31P279star.tsv
# !printf "id\tnode1\tlabel\tnode2\nxxxx\tQ106810\tP988\t1234\n" \
    > ../../constraintsOP/testConstraints/claims.properties.tsv
# !printf "node1\tlabel\tnode2\tnode1;exampleQnode\nP988\tP2303\tQ106811\tQ106810\n" \
    > ../../constraintsOP/testConstraints/claims.type-constraints_exceptions.tsv
# !printf "node1\tlabel\tnode2\tnode1;exampleQnode\nP988\tP2303\tQ21502408\tQ106810\n" \
    > ../../constraintsOP/testConstraints/claims.type-constraints_mandSug.tsv
# !printf "node1\tlabel\tnode2\tnode1;exampleQnode\nP988\tP2303\tQ1350312\tQ106810\n" \
    > ../../constraintsOP/testConstraints/claims.type-constraints_classes.tsv
# !printf "node1\tlabel\tnode2\tnode1;exampleQnode\nP988\tP2303\tQ21503252\tQ106810\n" \
    > ../../constraintsOP/testConstraints/claims.type-constraints_relation.tsv

# %%
# !kgtk --debug query -i ../../constraintsOP/testConstraints/claims_truncated1.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../wikidata-20210215/derived.P31P279star.tsv.gz \
    --match "t: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2309]->(relConstVal), c: (rLabel)-[:P2316]->(typeConstVal), c: (rLabel)-[:P2308]->(parent), d: (node1)-[]->(par), c: (eLabel)-[:P2303]->(eNode)" \
    --where 'nodeProp.label = rLabel and relConstVal = "Q21503252" and typeConstVal = "Q21502408" and (par not in parent or (rLabel = eLabel and node1 not in eNode))' \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    --graph-cache ~/sqlite3_caches/mandConst001.sqlite3.db

# %%
# !kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.tsv.gz \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match "g: (node1)-[nodeProp:P988]->(node2), c: (rLabel)-[:P2309]->(relConstVal), c: (rLabel)-[:P2316]->(typeConstVal)" \
    --where 'nodeProp.label = rLabel and relConstVal = "Q21503252" and typeConstVal = "Q21502408"' \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P988.all.tsv \
    --graph-cache ~/sqlite3_caches/mandConst001.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P988.all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../wikidata-20210215/derived.P31P279star.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2308]->(parent), d: (node1)-[]->(par), c: (eLabel)-[:P2303]->(eNode)" \
    --where 'nodeProp.label = rLabel and (par = parent or (rLabel = eLabel and node1 = eNode))' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P988.correct.tsv \
    --graph-cache ~/sqlite3_caches/mandConst001.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P988.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P988.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P988.incorrect.tsv
# Out:
# [2021-03-07 16:53:31 sqlstore]: IMPORT graph directly into table graph_7 from /data/wd-correctness/gdrive-kgtk-dump-2020-12-07/claims.tsv.gz ...
# [2021-03-07 17:30:37 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_7_c1."id", graph_7_c1."node1", graph_7_c1."label", graph_7_c1."node2"
#      FROM graph_2 AS graph_2_c2, graph_2 AS graph_2_c3, graph_7 AS graph_7_c1
#      WHERE graph_2_c2."label"=?
#      AND graph_2_c3."label"=?
#      AND graph_7_c1."label"=?
#      AND graph_2_c2."node1"=graph_2_c3."node1"
#      AND ((graph_7_c1."label" = graph_2_c2."node1") AND ((graph_2_c2."node2" = ?) AND (graph_2_c3."node2" = ?)))
#   PARAS: ['P2309', 'P2316', 'P988', 'Q21503252', 'Q21502408']
# ---------------------------------------------
# [2021-03-07 17:30:37 sqlstore]: CREATE INDEX on table graph_7 column label ...
# [2021-03-07 17:56:17 sqlstore]: ANALYZE INDEX on table graph_7 column label ...
# [2021-03-07 17:59:27 sqlstore]: IMPORT graph directly into table graph_10 from /data/wd-correctness/constraintsOP/testConstraints/claims.type-constraints.mandatory.instanceOf.all.tsv ...
# [2021-03-07 17:59:28 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_10_c1."id", graph_5_c3."node1", graph_10_c1."label", graph_10_c1."node2", max(graph_2_c2."node2") "_aLias.node1;ancestor"
#      FROM graph_10 AS graph_10_c1, graph_2 AS graph_2_c2, graph_2 AS graph_2_c4, graph_5 AS graph_5_c3
#      WHERE graph_2_c2."label"=?
#      AND graph_2_c4."label"=?
#      AND graph_10_c1."node1"=graph_5_c3."node1"
#      AND ((graph_10_c1."label" = graph_2_c2."node1") AND ((graph_5_c3."node2" = graph_2_c2."node2") OR ((graph_2_c2."node1" = graph_2_c4."node1") AND (graph_5_c3."node1" = graph_2_c4."node2"))))
#      GROUP BY graph_10_c1."id", graph_5_c3."node1", graph_10_c1."label", graph_10_c1."node2"
#   PARAS: ['P2308', 'P2303']
# ---------------------------------------------
# [2021-03-07 17:59:28 sqlstore]: CREATE INDEX on table graph_10 column node1 ...
# [2021-03-07 17:59:28 sqlstore]: ANALYZE INDEX on table graph_10 column node1 ...

# %%
import pandas as pd
df2 = pd.read_csv("../../constraintsOP/typeConstraint/claims.type-constraints_all1.tsv",sep="\t")

# %%
# !cat ../../constraintsOP/typeConstraint/claims.type-constraints_all1.tsv
# Out:
# id	node1	label	node2	node2;wikidatatype
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q102496	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q105985	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q1140371	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q1151067	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q1197685	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q12047392	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q12798556	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q12804010	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q14659	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q15097084	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q15238777	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q1530022	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q15617994	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q17143723	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q176799	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q18616576	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q1864008	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q191072	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q20045456	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q21004260	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q213283	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q2135465	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q214995	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q216353	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q2385804	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q24962887	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q30634609	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q317557	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q329525	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q35535	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q372690	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q3917681	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q40357	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q4164871	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q42470	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q43229	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q43306178	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q473972	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q4992061	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q55876909	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q56061	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q618779	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q65554936	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q686822	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q689044	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q7397	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q7748	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q7843791	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q80071	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q8142	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q8161	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2308	Q895526	wikibase-item
# P1001-P2302-Q21503250-a4dbee5e-0	P1001	P2309	Q30208840	wikibase-item
# P1002-P2302-Q21503250-6ce54a7e-0	P1002	P2308	Q630010	wikibase-item
# P1002-P2302-Q21503250-6ce54a7e-0	P1002	P2309	Q21514624	wikibase-item
# P1004-P2302-Q21503250-ed1bc192-0	P1004	P2308	Q2221906	wikibase-item
# P1004-P2302-Q21503250-ed1bc192-0	P1004	P2308	Q23413	wikibase-item
# P1004-P2302-Q21503250-ed1bc192-0	P1004	P2308	Q3947	wikibase-item
# P1004-P2302-Q21503250-ed1bc192-0	P1004	P2308	Q41176	wikibase-item
# P1004-P2302-Q21503250-ed1bc192-0	P1004	P2308	Q88291	wikibase-item
# P1004-P2302-Q21503250-ed1bc192-0	P1004	P2309	Q21503252	wikibase-item
# P1006-P2302-Q21503250-2b55c1ef-0	P1006	P2308	Q1190554	wikibase-item
# P1006-P2302-Q21503250-2b55c1ef-0	P1006	P2308	Q15632617	wikibase-item
# P1006-P2302-Q21503250-2b55c1ef-0	P1006	P2308	Q16334295	wikibase-item
# P1006-P2302-Q21503250-2b55c1ef-0	P1006	P2308	Q20643955	wikibase-item
# P1006-P2302-Q21503250-2b55c1ef-0	P1006	P2308	Q215627	wikibase-item
# P1006-P2302-Q21503250-2b55c1ef-0	P1006	P2308	Q43229	wikibase-item
# P1006-P2302-Q21503250-2b55c1ef-0	P1006	P2308	Q61002	wikibase-item
# P1006-P2302-Q21503250-2b55c1ef-0	P1006	P2309	Q21503252	wikibase-item
# P1007-P2302-Q21503250-50843dff-0	P1007	P2308	Q43229	wikibase-item
# P1007-P2302-Q21503250-50843dff-0	P1007	P2308	Q5	wikibase-item
# P1007-P2302-Q21503250-50843dff-0	P1007	P2309	Q21503252	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q1002697	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q1003030	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q132241	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q13473501	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q14623646	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q16334295	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q170584	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q20830276	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q215627	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q33506	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q4164871	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q43229	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q5	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q618779	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q625994	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q68773434	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q729	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q735	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q7406919	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q8148	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2308	Q95074	wikibase-item
# P101-P2302-Q21503250-5e21a19f-0	P101	P2309	Q30208840	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2303	Q25173	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q11032	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q11424	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q13002315	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q14623646	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q16334295	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q1656682	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q19913602	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q21070568	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q22698	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q24354	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q41176	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q42889	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q43229	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q47461344	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q49848	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q5	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q625994	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q7725634	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2308	Q95074	wikibase-item
# P1015-P2302-Q21503250-fb5f2fe2-0	P1015	P2309	Q21503252	wikibase-item
# P1016-P2302-Q21503250-b9ad1cee-0	P1016	P2308	Q1022867	wikibase-item
# P1016-P2302-Q21503250-b9ad1cee-0	P1016	P2309	Q21503252	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2303	Q3803706	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2303	Q576951	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2308	Q1656682	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2308	Q2221906	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2308	Q3245975	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2308	Q41176	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2308	Q43229	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2308	Q4989906	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2308	Q5	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2308	Q811979	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2308	Q839954	wikibase-item
# P1017-P2302-Q21503250-c6cd87e3-0	P1017	P2309	Q21503252	wikibase-item
# P1018-P2302-Q21503250-54a43488-0	P1018	P2308	Q17376908	wikibase-item
# P1018-P2302-Q21503250-54a43488-0	P1018	P2309	Q21503252	wikibase-item
# P102-P2302-Q21503250-1947017f-0	P102	P2308	Q5	wikibase-item
# P102-P2302-Q21503250-1947017f-0	P102	P2308	Q95074	wikibase-item
# P102-P2302-Q21503250-1947017f-0	P102	P2309	Q21503252	wikibase-item
# P1021-P2302-Q21503250-27bbf14d-0	P1021	P2308	Q215627	wikibase-item
# P1021-P2302-Q21503250-27bbf14d-0	P1021	P2309	Q21514624	wikibase-item
# P1021-P2302-Q21503250-beb03e41-0	P1021	P2308	Q12737077	wikibase-item
# P1021-P2302-Q21503250-beb03e41-0	P1021	P2309	Q21503252	wikibase-item
# P1022-P2302-Q21503250-5e1a9f32-0	P1022	P2308	Q215627	wikibase-item
# P1022-P2302-Q21503250-5e1a9f32-0	P1022	P2309	Q21514624	wikibase-item
# P1022-P2302-Q21503250-ab8823a4-0	P1022	P2308	Q12737077	wikibase-item
# P1022-P2302-Q21503250-ab8823a4-0	P1022	P2309	Q21503252	wikibase-item
# P1023-P2302-Q21503250-81a54e0d-0	P1023	P2308	Q12737077	wikibase-item
# P1023-P2302-Q21503250-81a54e0d-0	P1023	P2309	Q21503252	wikibase-item
# P1023-P2302-Q21503250-82ef0a29-0	P1023	P2308	Q215627	wikibase-item
# P1023-P2302-Q21503250-82ef0a29-0	P1023	P2309	Q21514624	wikibase-item
# P1024-P2302-Q21503250-1b5cc455-0	P1024	P2308	Q215627	wikibase-item
# P1024-P2302-Q21503250-1b5cc455-0	P1024	P2309	Q21514624	wikibase-item
# P1024-P2302-Q21503250-8fda428d-0	P1024	P2308	Q12737077	wikibase-item
# P1024-P2302-Q21503250-8fda428d-0	P1024	P2309	Q21503252	wikibase-item
# P1026-P2302-Q21503250-fa3dbc8c-0	P1026	P2308	Q5	wikibase-item
# P1026-P2302-Q21503250-fa3dbc8c-0	P1026	P2309	Q21503252	wikibase-item
# P1027-P2302-Q21503250-ac2c48fd-0	P1027	P2308	Q16023913	wikibase-item
# P1027-P2302-Q21503250-ac2c48fd-0	P1027	P2308	Q189533	wikibase-item
# P1027-P2302-Q21503250-ac2c48fd-0	P1027	P2308	Q618779	wikibase-item
# P1027-P2302-Q21503250-ac2c48fd-0	P1027	P2309	Q30208840	wikibase-item
# P1028-P2302-Q21503250-8a54705c-0	P1028	P2308	Q223557	wikibase-item
# P1028-P2302-Q21503250-8a54705c-0	P1028	P2309	Q21503252	wikibase-item
# P103-P2302-Q21503250-8693b87d-0	P103	P2308	Q13002315	wikibase-item
# P103-P2302-Q21503250-8693b87d-0	P103	P2308	Q21070598	wikibase-item
# P103-P2302-Q21503250-8693b87d-0	P103	P2308	Q215627	wikibase-item
# P103-P2302-Q21503250-8693b87d-0	P103	P2308	Q3117863	wikibase-item
# P103-P2302-Q21503250-8693b87d-0	P103	P2308	Q41710	wikibase-item
# P103-P2302-Q21503250-8693b87d-0	P103	P2308	Q95074	wikibase-item
# P103-P2302-Q21503250-8693b87d-0	P103	P2309	Q21503252	wikibase-item
# P1030-P2302-Q21503250-21fa4193-0	P1030	P2308	Q1738955	wikibase-item
# P1030-P2302-Q21503250-21fa4193-0	P1030	P2308	Q39715	wikibase-item
# P1030-P2302-Q21503250-21fa4193-0	P1030	P2309	Q21503252	wikibase-item
# P1031-P2302-Q21503250-c06dcb65-0	P1031	P2308	Q10429085	wikibase-item
# P1031-P2302-Q21503250-c06dcb65-0	P1031	P2308	Q1505023	wikibase-item
# P1031-P2302-Q21503250-c06dcb65-0	P1031	P2308	Q1864008	wikibase-item
# P1031-P2302-Q21503250-c06dcb65-0	P1031	P2308	Q686822	wikibase-item
# P1031-P2302-Q21503250-c06dcb65-0	P1031	P2308	Q820655	wikibase-item
# P1031-P2302-Q21503250-c06dcb65-0	P1031	P2308	Q846882	wikibase-item
# P1031-P2302-Q21503250-c06dcb65-0	P1031	P2308	Q98491862	wikibase-item
# P1031-P2302-Q21503250-c06dcb65-0	P1031	P2308	Q99045339	wikibase-item
# P1031-P2302-Q21503250-c06dcb65-0	P1031	P2309	Q21503252	wikibase-item
# P1034-P2302-Q21503250-e54bf306-0	P1034	P2308	Q16521	wikibase-item
# P1034-P2302-Q21503250-e54bf306-0	P1034	P2309	Q21503252	wikibase-item
# P1035-P2302-Q21503250-064d00af-0	P1035	P2308	Q15632617	wikibase-item
# P1035-P2302-Q21503250-064d00af-0	P1035	P2308	Q5	wikibase-item
# P1035-P2302-Q21503250-064d00af-0	P1035	P2309	Q21503252	wikibase-item
# P1037-P2302-Q21503250-3f619704-0	P1037	P2308	Q14623646	wikibase-item
# P1037-P2302-Q21503250-3f619704-0	P1037	P2308	Q43229	wikibase-item
# P1037-P2302-Q21503250-3f619704-0	P1037	P2308	Q89753576	wikibase-item
# P1037-P2302-Q21503250-3f619704-0	P1037	P2309	Q21503252	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q1313923	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q15632617	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q1569167	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q15711870	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q15773347	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q16979650	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q178885	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q21070598	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q5	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q8436	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2308	Q95074	wikibase-item
# P1038-P2302-Q21503250-f6263e3f-0	P1038	P2309	Q21503252	wikibase-item
# P1040-P2302-Q21503250-8fa46a7c-0	P1040	P2303	Q1218097	wikibase-item
# P1040-P2302-Q21503250-8fa46a7c-0	P1040	P2308	Q11424	wikibase-item
# P1040-P2302-Q21503250-8fa46a7c-0	P1040	P2308	Q15416	wikibase-item
# P1040-P2302-Q21503250-8fa46a7c-0	P1040	P2308	Q21191270	wikibase-item
# P1040-P2302-Q21503250-8fa46a7c-0	P1040	P2308	Q24856	wikibase-item
# P1040-P2302-Q21503250-8fa46a7c-0	P1040	P2308	Q526877	wikibase-item
# P1040-P2302-Q21503250-8fa46a7c-0	P1040	P2309	Q21503252	wikibase-item
# P1041-P2302-Q21503250-10eb8c0c-0	P1041	P2308	Q1466064	wikibase-item
# P1041-P2302-Q21503250-10eb8c0c-0	P1041	P2309	Q21514624	wikibase-item
# P1042-P2302-Q21503250-a2ce23d0-0	P1042	P2308	Q1002697	wikibase-item
# P1042-P2302-Q21503250-a2ce23d0-0	P1042	P2308	Q1700470	wikibase-item
# P1042-P2302-Q21503250-a2ce23d0-0	P1042	P2309	Q21503252	wikibase-item
# P1043-P2302-Q21503250-2d576e67-0	P1043	P2308	Q215627	wikibase-item
# P1043-P2302-Q21503250-2d576e67-0	P1043	P2309	Q21514624	wikibase-item
# P1043-P2302-Q21503250-dbf050b5-0	P1043	P2308	Q12737077	wikibase-item
# P1043-P2302-Q21503250-dbf050b5-0	P1043	P2309	Q21503252	wikibase-item
# P1046-P2302-Q21503250-ca361897-0	P1046	P2308	Q44559	wikibase-item
# P1046-P2302-Q21503250-ca361897-0	P1046	P2309	Q21503252	wikibase-item
# P1047-P2302-Q21503250-9bb87caf-0	P1047	P2308	Q5	wikibase-item
# P1047-P2302-Q21503250-9bb87caf-0	P1047	P2309	Q21503252	wikibase-item
# P1048-P2302-Q21503250-60d15179-0	P1048	P2308	Q5	wikibase-item
# P1048-P2302-Q21503250-60d15179-0	P1048	P2309	Q21503252	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2308	Q1509831	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2308	Q1595289	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2308	Q17624054	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2308	Q178885	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2308	Q187616	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2308	Q190	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2308	Q193291	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2308	Q4588528	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2308	Q5	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2308	Q95074	wikibase-item
# P1049-P2302-Q21503250-7cdb9992-0	P1049	P2309	Q30208840	wikibase-item
# P105-P2302-Q21503250-0574c7d4-0	P105	P2308	Q16521	wikibase-item
# P105-P2302-Q21503250-0574c7d4-0	P105	P2309	Q21503252	wikibase-item
# P105-P2302-Q21503250-0574c7d4-0	P105	P2316	Q21502408	wikibase-item
# P1050-P2302-Q21503250-d3730696-0	P1050	P2308	Q15304597	wikibase-item
# P1050-P2302-Q21503250-d3730696-0	P1050	P2308	Q215627	wikibase-item
# P1050-P2302-Q21503250-d3730696-0	P1050	P2308	Q30612	wikibase-item
# P1050-P2302-Q21503250-d3730696-0	P1050	P2308	Q4915012	wikibase-item
# P1050-P2302-Q21503250-d3730696-0	P1050	P2308	Q729	wikibase-item
# P1050-P2302-Q21503250-d3730696-0	P1050	P2308	Q95074	wikibase-item
# P1050-P2302-Q21503250-d3730696-0	P1050	P2309	Q21503252	wikibase-item
# P1052-P2302-Q21503250-1a12d916-0	P1052	P2308	Q12737077	wikibase-item
# P1052-P2302-Q21503250-1a12d916-0	P1052	P2309	Q21503252	wikibase-item
# P1052-P2302-Q21503250-28a8c34a-0	P1052	P2308	Q215627	wikibase-item
# P1052-P2302-Q21503250-28a8c34a-0	P1052	P2309	Q21514624	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q12737077	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q13226383	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q1408286	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q16686022	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q177634	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q1914636	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q2207288	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q268592	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q28640	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q3249551	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q327333	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q431289	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q43229	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q5	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q8148	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2308	Q820477	wikibase-item
# P1056-P2302-Q21503250-c121d9d8-0	P1056	P2309	Q30208840	wikibase-item
# P1057-P2302-Q21503250-3a2b779c-0	P1057	P2308	Q1458444	wikibase-item
# P1057-P2302-Q21503250-3a2b779c-0	P1057	P2308	Q15304597	wikibase-item
# P1057-P2302-Q21503250-3a2b779c-0	P1057	P2308	Q7187	wikibase-item
# P1057-P2302-Q21503250-3a2b779c-0	P1057	P2309	Q21503252	wikibase-item
# P1058-P2302-Q21503250-95d7038d-0	P1058	P2308	Q1002697	wikibase-item
# P1058-P2302-Q21503250-95d7038d-0	P1058	P2309	Q21503252	wikibase-item
# P1059-P2302-Q21503250-f4521351-0	P1059	P2308	Q43229	wikibase-item
# P1059-P2302-Q21503250-f4521351-0	P1059	P2309	Q21503252	wikibase-item
# P106-P2302-Q21503250-aa983c2f-0	P106	P2303	Q99393050	wikibase-item
# P106-P2302-Q21503250-aa983c2f-0	P106	P2308	Q11012	wikibase-item
# P106-P2302-Q21503250-aa983c2f-0	P106	P2308	Q14514600	wikibase-item
# P106-P2302-Q21503250-aa983c2f-0	P106	P2308	Q16334295	wikibase-item
# P106-P2302-Q21503250-aa983c2f-0	P106	P2308	Q21070598	wikibase-item
# P106-P2302-Q21503250-aa983c2f-0	P106	P2308	Q215627	wikibase-item
# P106-P2302-Q21503250-aa983c2f-0	P106	P2308	Q5	wikibase-item
# P106-P2302-Q21503250-aa983c2f-0	P106	P2308	Q729	wikibase-item
# P106-P2302-Q21503250-aa983c2f-0	P106	P2308	Q95074	wikibase-item
# P106-P2302-Q21503250-aa983c2f-0	P106	P2309	Q21503252	wikibase-item
# P1060-P2302-Q21503250-231575d6-0	P1060	P2308	Q12136	wikibase-item
# P1060-P2302-Q21503250-231575d6-0	P1060	P2309	Q21514624	wikibase-item
# P1066-P2302-Q21503250-97fcdff5-0	P1066	P2308	Q5	wikibase-item
# P1066-P2302-Q21503250-97fcdff5-0	P1066	P2308	Q95074	wikibase-item
# P1066-P2302-Q21503250-97fcdff5-0	P1066	P2309	Q21503252	wikibase-item
# P1067-P2302-Q21503250-4c08f7a3-0	P1067	P2308	Q1077333	wikibase-item
# P1067-P2302-Q21503250-4c08f7a3-0	P1067	P2309	Q21503252	wikibase-item
# P1067-P2302-Q21503250-4c08f7a3-0	P1067	P2316	Q21502408	wikibase-item
# P1068-P2302-Q21503250-1a9b7d24-0	P1068	P2308	Q1815901	wikibase-item
# P1068-P2302-Q21503250-1a9b7d24-0	P1068	P2309	Q30208840	wikibase-item
# P1069-P2302-Q21503250-3bec09ac-0	P1069	P2308	Q12737077	wikibase-item
# P1069-P2302-Q21503250-3bec09ac-0	P1069	P2309	Q21503252	wikibase-item
# P1069-P2302-Q21503250-3c3c5670-0	P1069	P2308	Q215627	wikibase-item
# P1069-P2302-Q21503250-3c3c5670-0	P1069	P2309	Q21514624	wikibase-item
# P1071-P2302-Q21503250-348f592b-0	P1071	P2308	Q10929058	wikibase-item
# P1071-P2302-Q21503250-348f592b-0	P1071	P2308	Q17334923	wikibase-item
# P1071-P2302-Q21503250-348f592b-0	P1071	P2308	Q17489659	wikibase-item
# P1071-P2302-Q21503250-348f592b-0	P1071	P2308	Q2095	wikibase-item
# P1071-P2302-Q21503250-348f592b-0	P1071	P2308	Q3231690	wikibase-item
# P1071-P2302-Q21503250-348f592b-0	P1071	P2308	Q3407658	wikibase-item
# P1071-P2302-Q21503250-348f592b-0	P1071	P2308	Q386724	wikibase-item
# P1071-P2302-Q21503250-348f592b-0	P1071	P2308	Q559026	wikibase-item
# P1071-P2302-Q21503250-348f592b-0	P1071	P2308	Q8205328	wikibase-item
# P1071-P2302-Q21503250-348f592b-0	P1071	P2309	Q30208840	wikibase-item
# P1072-P2302-Q21503250-6bfcb8da-0	P1072	P2308	Q20826013	wikibase-item
# P1072-P2302-Q21503250-6bfcb8da-0	P1072	P2308	Q7397	wikibase-item
# P1072-P2302-Q21503250-6bfcb8da-0	P1072	P2309	Q21503252	wikibase-item
# P1073-P2302-Q21503250-ffeaca13-0	P1073	P2308	Q166142	wikibase-item
# P1073-P2302-Q21503250-ffeaca13-0	P1073	P2308	Q2858615	wikibase-item
# P1073-P2302-Q21503250-ffeaca13-0	P1073	P2308	Q7397	wikibase-item
# P1073-P2302-Q21503250-ffeaca13-0	P1073	P2309	Q30208840	wikibase-item
# P1074-P2302-Q21503250-4e8277aa-0	P1074	P2303	Q14897293	wikibase-item
# P1074-P2302-Q21503250-4e8277aa-0	P1074	P2308	Q14897293	wikibase-item
# P1074-P2302-Q21503250-4e8277aa-0	P1074	P2308	Q24334685	wikibase-item
# P1074-P2302-Q21503250-4e8277aa-0	P1074	P2309	Q30208840	wikibase-item
# P1075-P2302-Q21503250-69c6c303-0	P1075	P2308	Q15690029	wikibase-item
# P1075-P2302-Q21503250-69c6c303-0	P1075	P2308	Q38723	wikibase-item
# P1075-P2302-Q21503250-69c6c303-0	P1075	P2309	Q21503252	wikibase-item
# P1078-P2302-Q21503250-39682c2e-0	P1078	P2308	Q630010	wikibase-item
# P1078-P2302-Q21503250-39682c2e-0	P1078	P2309	Q21514624	wikibase-item
# P1079-P2302-Q21503250-3c9d73dc-0	P1079	P2308	Q40218	wikibase-item
# P1079-P2302-Q21503250-3c9d73dc-0	P1079	P2308	Q5916	wikibase-item
# P1079-P2302-Q21503250-3c9d73dc-0	P1079	P2309	Q21503252	wikibase-item
# P108-P2302-Q21503250-51300b0a-0	P108	P2308	Q15632617	wikibase-item
# P108-P2302-Q21503250-51300b0a-0	P108	P2308	Q3895768	wikibase-item
# P108-P2302-Q21503250-51300b0a-0	P108	P2308	Q5	wikibase-item
# P108-P2302-Q21503250-51300b0a-0	P108	P2308	Q95074	wikibase-item
# P108-P2302-Q21503250-51300b0a-0	P108	P2309	Q21503252	wikibase-item
# P1080-P2302-Q21503250-6ce7d08c-0	P1080	P2303	Q2915157	wikibase-item
# P1080-P2302-Q21503250-6ce7d08c-0	P1080	P2308	Q13002315	wikibase-item
# P1080-P2302-Q21503250-6ce7d08c-0	P1080	P2308	Q14514600	wikibase-item
# P1080-P2302-Q21503250-6ce7d08c-0	P1080	P2308	Q14897293	wikibase-item
# P1080-P2302-Q21503250-6ce7d08c-0	P1080	P2308	Q15831596	wikibase-item
# P1080-P2302-Q21503250-6ce7d08c-0	P1080	P2308	Q21070598	wikibase-item
# P1080-P2302-Q21503250-6ce7d08c-0	P1080	P2308	Q24334685	wikibase-item
# P1080-P2302-Q21503250-6ce7d08c-0	P1080	P2308	Q978	wikibase-item
# P1080-P2302-Q21503250-6ce7d08c-0	P1080	P2309	Q30208840	wikibase-item
# P1081-P2302-Q21503250-c2d7aeb3-0	P1081	P2308	Q3624078	wikibase-item
# P1081-P2302-Q21503250-c2d7aeb3-0	P1081	P2308	Q56061	wikibase-item
# P1081-P2302-Q21503250-c2d7aeb3-0	P1081	P2309	Q21503252	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2303	Q2	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2304	P17	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q1145276	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q149621	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q1496967	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q15042037	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q15831598	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q159313	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q16521	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q188509	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q1907114	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q1964689	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q23442	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q33837	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q38829	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q41710	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q42523	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q486972	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q5107	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q515	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q51883617	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2308	Q7275	wikibase-item
# P1082-P2302-Q21503250-813b0c80-0	P1082	P2309	Q21503252	wikibase-item
# P1083-P2302-Q21503250-d6e73191-0	P1083	P2308	Q132241	wikibase-item
# P1083-P2302-Q21503250-d6e73191-0	P1083	P2308	Q15720793	wikibase-item
# P1083-P2302-Q21503250-d6e73191-0	P1083	P2308	Q1875621	wikibase-item
# P1083-P2302-Q21503250-d6e73191-0	P1083	P2308	Q20871196	wikibase-item
# P1083-P2302-Q21503250-d6e73191-0	P1083	P2308	Q42889	wikibase-item
# P1083-P2302-Q21503250-d6e73191-0	P1083	P2308	Q811430	wikibase-item
# P1083-P2302-Q21503250-d6e73191-0	P1083	P2308	Q811979	wikibase-item
# P1083-P2302-Q21503250-d6e73191-0	P1083	P2309	Q30208840	wikibase-item
# P1084-P2302-Q21503250-25beb215-0	P1084	P2308	Q3331189	wikibase-item
# P1084-P2302-Q21503250-25beb215-0	P1084	P2309	Q21503252	wikibase-item
# P1085-P2302-Q21503250-36e38650-0	P1085	P2308	Q3331189	wikibase-item
# P1085-P2302-Q21503250-36e38650-0	P1085	P2308	Q47461344	wikibase-item
# P1085-P2302-Q21503250-36e38650-0	P1085	P2309	Q21503252	wikibase-item
# P1086-P2302-Q21503250-a65b7a2a-0	P1086	P2308	Q11344	wikibase-item
# P1086-P2302-Q21503250-a65b7a2a-0	P1086	P2308	Q25276	wikibase-item
# P1086-P2302-Q21503250-a65b7a2a-0	P1086	P2308	Q37147	wikibase-item
# P1086-P2302-Q21503250-a65b7a2a-0	P1086	P2309	Q21503252	wikibase-item
# P1087-P2302-Q21503250-5dff0300-0	P1087	P2308	Q40056	wikibase-item
# P1087-P2302-Q21503250-5dff0300-0	P1087	P2308	Q5	wikibase-item
# P1087-P2302-Q21503250-5dff0300-0	P1087	P2309	Q21503252	wikibase-item
# P1087-P2302-Q21503250-5dff0300-0	P1087	P2316	Q21502408	wikibase-item
# P1088-P2302-Q21503250-2a15fe6e-0	P1088	P2308	Q7946	wikibase-item
# P1088-P2302-Q21503250-2a15fe6e-0	P1088	P2309	Q21514624	wikibase-item
# P109-P2302-Q21503250-7ab98cba-0	P109	P2303	Q2977936	wikibase-item
# P109-P2302-Q21503250-7ab98cba-0	P109	P2308	Q10648343	wikibase-item
# P109-P2302-Q21503250-7ab98cba-0	P109	P2308	Q146	wikibase-item
# P109-P2302-Q21503250-7ab98cba-0	P109	P2308	Q5	wikibase-item
# P109-P2302-Q21503250-7ab98cba-0	P109	P2308	Q8436	wikibase-item
# P109-P2302-Q21503250-7ab98cba-0	P109	P2308	Q95074	wikibase-item
# P109-P2302-Q21503250-7ab98cba-0	P109	P2309	Q21503252	wikibase-item
# P1090-P2302-Q21503250-706c0287-0	P1090	P2308	Q6999	wikibase-item
# P1090-P2302-Q21503250-706c0287-0	P1090	P2308	Q751989	wikibase-item
# P1090-P2302-Q21503250-706c0287-0	P1090	P2309	Q21503252	wikibase-item
# P1090-P2302-Q21503250-706c0287-0	P1090	P2316	Q21502408	wikibase-item
# P1092-P2302-Q21503250-ce1c5ddd-0	P1092	P2303	Q38782	wikibase-item
# P1092-P2302-Q21503250-ce1c5ddd-0	P1092	P2308	Q1002697	wikibase-item
# P1092-P2302-Q21503250-ce1c5ddd-0	P1092	P2308	Q10929058	wikibase-item
# P1092-P2302-Q21503250-ce1c5ddd-0	P1092	P2308	Q10943	wikibase-item
# P1092-P2302-Q21503250-ce1c5ddd-0	P1092	P2308	Q2424752	wikibase-item
# P1092-P2302-Q21503250-ce1c5ddd-0	P1092	P2308	Q3331189	wikibase-item
# P1092-P2302-Q21503250-ce1c5ddd-0	P1092	P2308	Q559026	wikibase-item
# P1092-P2302-Q21503250-ce1c5ddd-0	P1092	P2309	Q21503252	wikibase-item
# P1093-P2302-Q21503250-d44082e9-0	P1093	P2308	Q11446	wikibase-item
# P1093-P2302-Q21503250-d44082e9-0	P1093	P2309	Q21503252	wikibase-item
# P1096-P2302-Q21503250-134cbe97-0	P1096	P2308	Q15831598	wikibase-item
# P1096-P2302-Q21503250-134cbe97-0	P1096	P2308	Q40218	wikibase-item
# P1096-P2302-Q21503250-134cbe97-0	P1096	P2308	Q6999	wikibase-item
# P1096-P2302-Q21503250-134cbe97-0	P1096	P2309	Q21503252	wikibase-item
# P1096-P2302-Q21503250-134cbe97-0	P1096	P2316	Q21502408	wikibase-item
# P1098-P2302-Q21503250-92eda386-0	P1098	P2308	Q17376908	wikibase-item
# P1098-P2302-Q21503250-92eda386-0	P1098	P2308	Q941501	wikibase-item
# P1098-P2302-Q21503250-92eda386-0	P1098	P2309	Q21503252	wikibase-item
# P1098-P2302-Q21503250-92eda386-0	P1098	P2316	Q21502408	wikibase-item
# P1099-P2302-Q21503250-3d749fdd-0	P1099	P2308	Q11446	wikibase-item
# P1099-P2302-Q21503250-3d749fdd-0	P1099	P2309	Q21503252	wikibase-item
# P110-P2302-Q21503250-2919602a-0	P110	P2308	Q3331189	wikibase-item
# P110-P2302-Q21503250-2919602a-0	P110	P2308	Q386724	wikibase-item
# P110-P2302-Q21503250-2919602a-0	P110	P2309	Q21503252	wikibase-item
# P1100-P2302-Q21503250-47328b32-0	P1100	P2308	Q171043	wikibase-item
# P1100-P2302-Q21503250-47328b32-0	P1100	P2308	Q630010	wikibase-item
# P1100-P2302-Q21503250-47328b32-0	P1100	P2309	Q21514624	wikibase-item
# P1101-P2302-Q21503250-fc0f4527-0	P1101	P2308	Q15720793	wikibase-item
# P1101-P2302-Q21503250-fc0f4527-0	P1101	P2308	Q811979	wikibase-item
# P1101-P2302-Q21503250-fc0f4527-0	P1101	P2309	Q21503252	wikibase-item
# P1102-P2302-Q21503250-a9b8025a-0	P1102	P2308	Q6999	wikibase-item
# P1102-P2302-Q21503250-a9b8025a-0	P1102	P2309	Q21503252	wikibase-item
# P1103-P2302-Q21503250-63ce2b69-0	P1103	P2308	Q548662	wikibase-item
# P1103-P2302-Q21503250-63ce2b69-0	P1103	P2309	Q21503252	wikibase-item
# P1103-P2302-Q21503250-63ce2b69-0	P1103	P2316	Q21502408	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q10870555	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q11826511	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q1238720	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q1266946	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q1508646	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q16324495	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q190399	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q191067	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q1980247	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q2018524	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q213369	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q28869365	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q3331189	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q49848	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q56855534	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q571	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q59126	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q732577	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q87167	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2308	Q947859	wikibase-item
# P1104-P2302-Q21503250-52191d1d-0	P1104	P2309	Q30208840	wikibase-item
# P1106-P2302-Q21503250-ed7f96d0-0	P1106	P2308	Q14795564	wikibase-item
# P1106-P2302-Q21503250-ed7f96d0-0	P1106	P2309	Q21503252	wikibase-item
# P1108-P2302-Q21503250-a3c4b0f5-0	P1108	P2308	Q11344	wikibase-item
# P1108-P2302-Q21503250-a3c4b0f5-0	P1108	P2309	Q21503252	wikibase-item
# P1109-P2302-Q21503250-7181f6a7-0	P1109	P2308	Q7946	wikibase-item
# P1109-P2302-Q21503250-7181f6a7-0	P1109	P2308	Q79529	wikibase-item
# P1109-P2302-Q21503250-7181f6a7-0	P1109	P2309	Q30208840	wikibase-item
# P111-P2302-Q21503250-7e52ab03-0	P111	P2308	Q173227	wikibase-item
# P111-P2302-Q21503250-7e52ab03-0	P111	P2308	Q47574	wikibase-item
# P111-P2302-Q21503250-7e52ab03-0	P111	P2309	Q30208840	wikibase-item
# P1110-P2302-Q21503250-f04c56d3-0	P1110	P2308	Q1656682	wikibase-item
# P1110-P2302-Q21503250-f04c56d3-0	P1110	P2308	Q386724	wikibase-item
# P1110-P2302-Q21503250-f04c56d3-0	P1110	P2309	Q21503252	wikibase-item
# P1111-P2302-Q21503250-c0313de7-0	P1111	P2308	Q189760	wikibase-item
# P1111-P2302-Q21503250-c0313de7-0	P1111	P2309	Q21503252	wikibase-item
# P1115-P2302-Q21503250-c1f63fac-0	P1115	P2308	Q750277	wikibase-item
# P1115-P2302-Q21503250-c1f63fac-0	P1115	P2309	Q21503252	wikibase-item
# P1115-P2302-Q21503250-c1f63fac-0	P1115	P2316	Q21502408	wikibase-item
# P1117-P2302-Q21503250-1f037d8e-0	P1117	P2308	Q11173	wikibase-item
# P1117-P2302-Q21503250-1f037d8e-0	P1117	P2308	Q36496	wikibase-item
# P1117-P2302-Q21503250-1f037d8e-0	P1117	P2309	Q21503252	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q14623646	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q16334295	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q1656682	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q170584	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q177634	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q18127	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q2217301	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q35127	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q3895768	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q43229	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q4830453	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q49773	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q58778	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q60031086	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q618123	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q618779	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q7257	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q732577	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2308	Q811979	wikibase-item
# P112-P2302-Q21503250-32c1465a-0	P112	P2309	Q21503252	wikibase-item
# P1120-P2302-Q21503250-6917a9d9-0	P1120	P2303	Q2165983	wikibase-item
# P1120-P2302-Q21503250-6917a9d9-0	P1120	P2308	Q1190554	wikibase-item
# P1120-P2302-Q21503250-6917a9d9-0	P1120	P2308	Q14136353	wikibase-item
# P1120-P2302-Q21503250-6917a9d9-0	P1120	P2309	Q21503252	wikibase-item
# P1121-P2302-Q21503250-4bbaee5f-0	P1121	P2308	Q11344	wikibase-item
# P1121-P2302-Q21503250-4bbaee5f-0	P1121	P2309	Q21503252	wikibase-item
# P1121-P2302-Q21503250-4bbaee5f-0	P1121	P2316	Q21502408	wikibase-item
# P1122-P2302-Q21503250-15e0c291-0	P1122	P2308	Q1621273	wikibase-item
# P1122-P2302-Q21503250-15e0c291-0	P1122	P2308	Q25276	wikibase-item
# P1122-P2302-Q21503250-15e0c291-0	P1122	P2309	Q21514624	wikibase-item
# P1123-P2302-Q21503250-b57a86e2-0	P1123	P2308	Q22675015	wikibase-item
# P1123-P2302-Q21503250-b57a86e2-0	P1123	P2308	Q25276	wikibase-item
# P1123-P2302-Q21503250-b57a86e2-0	P1123	P2309	Q21503252	wikibase-item
# P1128-P2302-Q21503250-7506d009-0	P1128	P2308	Q43229	wikibase-item
# P1128-P2302-Q21503250-7506d009-0	P1128	P2309	Q21503252	wikibase-item
# P1129-P2302-Q21503250-82c520f2-0	P1129	P2308	Q5	wikibase-item
# P1129-P2302-Q21503250-82c520f2-0	P1129	P2309	Q21503252	wikibase-item
# P1129-P2302-Q21503250-82c520f2-0	P1129	P2316	Q21502408	wikibase-item
# P113-P2302-Q21503250-72fd59fa-0	P113	P2308	Q465909	wikibase-item
# P113-P2302-Q21503250-72fd59fa-0	P113	P2308	Q46970	wikibase-item
# P113-P2302-Q21503250-72fd59fa-0	P113	P2309	Q21503252	wikibase-item
# P1132-P2302-Q21503250-8fe0eba4-0	P1132	P2308	Q1190554	wikibase-item
# P1132-P2302-Q21503250-8fe0eba4-0	P1132	P2308	Q170584	wikibase-item
# P1132-P2302-Q21503250-8fe0eba4-0	P1132	P2308	Q321839	wikibase-item
# P1132-P2302-Q21503250-8fe0eba4-0	P1132	P2308	Q526999	wikibase-item
# P1132-P2302-Q21503250-8fe0eba4-0	P1132	P2309	Q30208840	wikibase-item
# P1133-P2302-Q21503250-4fe25ef2-0	P1133	P2308	Q2221906	wikibase-item
# P1133-P2302-Q21503250-4fe25ef2-0	P1133	P2308	Q618123	wikibase-item
# P1133-P2302-Q21503250-4fe25ef2-0	P1133	P2309	Q21503252	wikibase-item
# P1135-P2302-Q21503250-e7d33dcb-0	P1135	P2308	Q16521	wikibase-item
# P1135-P2302-Q21503250-e7d33dcb-0	P1135	P2309	Q21503252	wikibase-item
# P1138-P2302-Q21503250-979e8018-0	P1138	P2303	Q1005	wikibase-item
# P1138-P2302-Q21503250-979e8018-0	P1138	P2303	Q1008	wikibase-item
# P1138-P2302-Q21503250-979e8018-0	P1138	P2303	Q17252	wikibase-item
# P1138-P2302-Q21503250-979e8018-0	P1138	P2303	Q209327	wikibase-item
# P1138-P2302-Q21503250-979e8018-0	P1138	P2303	Q4412	wikibase-item
# P1138-P2302-Q21503250-979e8018-0	P1138	P2303	Q4648	wikibase-item
# P1138-P2302-Q21503250-979e8018-0	P1138	P2303	Q916	wikibase-item
# P1138-P2302-Q21503250-979e8018-0	P1138	P2308	Q16334295	wikibase-item
# P1138-P2302-Q21503250-979e8018-0	P1138	P2308	Q5	wikibase-item
# P1138-P2302-Q21503250-979e8018-0	P1138	P2309	Q21503252	wikibase-item
# P1139-P2302-Q21503250-6e409484-0	P1139	P2308	Q811430	wikibase-item
# P1139-P2302-Q21503250-6e409484-0	P1139	P2309	Q21503252	wikibase-item
# P1139-P2302-Q21503250-6e409484-0	P1139	P2316	Q21502408	wikibase-item
# P114-P2302-Q21503250-4e3ebc1a-0	P114	P2308	Q46970	wikibase-item
# P114-P2302-Q21503250-4e3ebc1a-0	P114	P2309	Q21503252	wikibase-item
# P1140-P2302-Q21503250-ae9e7625-0	P1140	P2308	Q15620181	wikibase-item
# P1140-P2302-Q21503250-ae9e7625-0	P1140	P2308	Q34985575	wikibase-item
# P1140-P2302-Q21503250-ae9e7625-0	P1140	P2308	Q618299	wikibase-item
# P1140-P2302-Q21503250-ae9e7625-0	P1140	P2309	Q21503252	wikibase-item
# P1140-P2302-Q21503250-ae9e7625-0	P1140	P2316	Q21502408	wikibase-item
# P1141-P2302-Q21503250-c3b87dd9-0	P1141	P2308	Q1183543	wikibase-item
# P1141-P2302-Q21503250-c3b87dd9-0	P1141	P2308	Q1815901	wikibase-item
# P1141-P2302-Q21503250-c3b87dd9-0	P1141	P2308	Q210729	wikibase-item
# P1141-P2302-Q21503250-c3b87dd9-0	P1141	P2309	Q30208840	wikibase-item
# P1143-P2302-Q21503250-06bd97bb-0	P1143	P2308	Q3331189	wikibase-item
# P1143-P2302-Q21503250-06bd97bb-0	P1143	P2308	Q571	wikibase-item
# P1143-P2302-Q21503250-06bd97bb-0	P1143	P2309	Q21503252	wikibase-item
# P1144-P2302-Q21503250-7d9b7009-0	P1144	P2308	Q11424	wikibase-item
# P1144-P2302-Q21503250-7d9b7009-0	P1144	P2308	Q2217301	wikibase-item
# P1144-P2302-Q21503250-7d9b7009-0	P1144	P2308	Q24862	wikibase-item
# P1144-P2302-Q21503250-7d9b7009-0	P1144	P2308	Q3331189	wikibase-item
# P1144-P2302-Q21503250-7d9b7009-0	P1144	P2308	Q34508	wikibase-item
# P1144-P2302-Q21503250-7d9b7009-0	P1144	P2308	Q3918	wikibase-item
# P1144-P2302-Q21503250-7d9b7009-0	P1144	P2309	Q21503252	wikibase-item
# P1145-P2302-Q21503250-24063c08-0	P1145	P2308	Q15101896	wikibase-item
# P1145-P2302-Q21503250-24063c08-0	P1145	P2308	Q223557	wikibase-item
# P1145-P2302-Q21503250-24063c08-0	P1145	P2309	Q21503252	wikibase-item
# P1145-P2302-Q21503250-24063c08-0	P1145	P2316	Q21502408	wikibase-item
# P1148-P2302-Q21503250-5c2fa512-0	P1148	P2308	Q25276	wikibase-item
# P1148-P2302-Q21503250-5c2fa512-0	P1148	P2308	Q37147	wikibase-item
# P1148-P2302-Q21503250-5c2fa512-0	P1148	P2309	Q21503252	wikibase-item
# P115-P2302-Q21503250-cac6557d-0	P115	P2308	Q27020041	wikibase-item
# P115-P2302-Q21503250-cac6557d-0	P115	P2308	Q4438121	wikibase-item
# P115-P2302-Q21503250-cac6557d-0	P115	P2309	Q21503252	wikibase-item
# P1154-P2302-Q21503250-a7df00de-0	P1154	P2308	Q47461344	wikibase-item
# P1154-P2302-Q21503250-a7df00de-0	P1154	P2309	Q21503252	wikibase-item
# P1156-P2302-Q21503250-317c202e-0	P1156	P2308	Q1002697	wikibase-item
# P1156-P2302-Q21503250-317c202e-0	P1156	P2309	Q21503252	wikibase-item
# P1158-P2302-Q21503250-24dfab1c-0	P1158	P2308	Q42889	wikibase-item
# P1158-P2302-Q21503250-24dfab1c-0	P1158	P2308	Q5916	wikibase-item
# P1158-P2302-Q21503250-24dfab1c-0	P1158	P2309	Q21503252	wikibase-item
# P1159-P2302-Q21503250-66267792-0	P1159	P2308	Q1002697	wikibase-item
# P1159-P2302-Q21503250-66267792-0	P1159	P2309	Q21503252	wikibase-item
# P1159-P2302-Q21503250-66267792-0	P1159	P2316	Q21502408	wikibase-item
# P1160-P2302-Q21503250-6404dba1-0	P1160	P2308	Q737498	wikibase-item
# P1160-P2302-Q21503250-6404dba1-0	P1160	P2309	Q21503252	wikibase-item
# P1161-P2302-Q21503250-71285b6d-0	P1161	P2308	Q5633421	wikibase-item
# P1161-P2302-Q21503250-71285b6d-0	P1161	P2309	Q21503252	wikibase-item
# P1163-P2302-Q21503250-523e3726-0	P1163	P2308	Q235557	wikibase-item
# P1163-P2302-Q21503250-523e3726-0	P1163	P2309	Q30208840	wikibase-item
# P1164-P2302-Q21503250-94d09531-0	P1164	P2308	Q1057968	wikibase-item
# P1164-P2302-Q21503250-94d09531-0	P1164	P2309	Q21503252	wikibase-item
# P1165-P2302-Q21503250-5ed79614-0	P1165	P2308	Q15238535	wikibase-item
# P1165-P2302-Q21503250-5ed79614-0	P1165	P2308	Q15707583	wikibase-item
# P1165-P2302-Q21503250-5ed79614-0	P1165	P2308	Q95074	wikibase-item
# P1165-P2302-Q21503250-5ed79614-0	P1165	P2308	Q989255	wikibase-item
# P1165-P2302-Q21503250-5ed79614-0	P1165	P2309	Q21503252	wikibase-item
# P1167-P2302-Q21503250-7e36e5f5-0	P1167	P2308	Q43229	wikibase-item
# P1167-P2302-Q21503250-7e36e5f5-0	P1167	P2309	Q21503252	wikibase-item
# P1167-P2302-Q21503250-7e36e5f5-0	P1167	P2316	Q21502408	wikibase-item
# P1167-P2302-Q21503250-86c94e28-0	P1167	P2308	Q38723	wikibase-item
# P1167-P2302-Q21503250-86c94e28-0	P1167	P2308	Q4830453	wikibase-item
# P1167-P2302-Q21503250-86c94e28-0	P1167	P2308	Q6881511	wikibase-item
# P1167-P2302-Q21503250-86c94e28-0	P1167	P2309	Q21503252	wikibase-item
# P1167-P2302-Q21503250-86c94e28-0	P1167	P2316	Q62026391	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q17143182	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q17310124	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q1891759	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q1964865	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q2312867	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q2463392	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q3048346	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q30969261	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q39513	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q43342	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q56435743	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q58258248	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q58258493	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2303	Q9281424	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2308	Q11173	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2308	Q17339814	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2308	Q2393187	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2308	Q72070508	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2308	Q81163	wikibase-item
# P117-P2302-Q21503250-40c23526-0	P117	P2309	Q21503252	wikibase-item
# P1170-P2302-Q21503250-df159c64-0	P1170	P2308	Q2424752	wikibase-item
# P1170-P2302-Q21503250-df159c64-0	P1170	P2309	Q21514624	wikibase-item
# P1171-P2302-Q21503250-3bfb7cce-0	P1171	P2308	Q11563	wikibase-item
# P1171-P2302-Q21503250-3bfb7cce-0	P1171	P2309	Q21503252	wikibase-item
# P1171-P2302-Q21503250-3bfb7cce-0	P1171	P2316	Q21502408	wikibase-item
# P1172-P2302-Q21503250-193c4bf7-0	P1172	P2308	Q11722303	wikibase-item
# P1172-P2302-Q21503250-193c4bf7-0	P1172	P2308	Q12015578	wikibase-item
# P1172-P2302-Q21503250-193c4bf7-0	P1172	P2308	Q13420058	wikibase-item
# P1172-P2302-Q21503250-193c4bf7-0	P1172	P2308	Q200547	wikibase-item
# P1172-P2302-Q21503250-193c4bf7-0	P1172	P2308	Q28045485	wikibase-item
# P1172-P2302-Q21503250-193c4bf7-0	P1172	P2308	Q313354	wikibase-item
# P1172-P2302-Q21503250-193c4bf7-0	P1172	P2308	Q5394548	wikibase-item
# P1172-P2302-Q21503250-193c4bf7-0	P1172	P2308	Q615980	wikibase-item
# P1172-P2302-Q21503250-193c4bf7-0	P1172	P2309	Q21503252	wikibase-item
# P1174-P2302-Q21503250-9f72111c-0	P1174	P2308	Q178706	wikibase-item
# P1174-P2302-Q21503250-9f72111c-0	P1174	P2308	Q464980	wikibase-item
# P1174-P2302-Q21503250-9f72111c-0	P1174	P2308	Q618123	wikibase-item
# P1174-P2302-Q21503250-9f72111c-0	P1174	P2309	Q21503252	wikibase-item
# P118-P2302-Q21503250-0197f981-0	P118	P2308	Q13406554	wikibase-item
# P118-P2302-Q21503250-0197f981-0	P118	P2308	Q15229207	wikibase-item
# P118-P2302-Q21503250-0197f981-0	P118	P2308	Q16510064	wikibase-item
# P118-P2302-Q21503250-0197f981-0	P118	P2308	Q4438121	wikibase-item
# P118-P2302-Q21503250-0197f981-0	P118	P2308	Q5	wikibase-item
# P118-P2302-Q21503250-0197f981-0	P118	P2309	Q21503252	wikibase-item
# P1181-P2302-Q21503250-a74d9144-0	P1181	P2308	Q11563	wikibase-item
# P1181-P2302-Q21503250-a74d9144-0	P1181	P2308	Q1441762	wikibase-item
# P1181-P2302-Q21503250-a74d9144-0	P1181	P2308	Q15132612	wikibase-item
# P1181-P2302-Q21503250-a74d9144-0	P1181	P2308	Q173227	wikibase-item
# P1181-P2302-Q21503250-a74d9144-0	P1181	P2308	Q202805	wikibase-item
# P1181-P2302-Q21503250-a74d9144-0	P1181	P2308	Q309314	wikibase-item
# P1181-P2302-Q21503250-a74d9144-0	P1181	P2308	Q47574	wikibase-item
# P1181-P2302-Q21503250-a74d9144-0	P1181	P2308	Q62944360	wikibase-item
# P1181-P2302-Q21503250-a74d9144-0	P1181	P2308	Q82990	wikibase-item
# P1181-P2302-Q21503250-a74d9144-0	P1181	P2309	Q30208840	wikibase-item
# P1183-P2302-Q21503250-5bf7bab8-0	P1183	P2308	Q355304	wikibase-item
# P1183-P2302-Q21503250-5bf7bab8-0	P1183	P2309	Q21503252	wikibase-item
# P1185-P2302-Q21503250-8bfd5a71-0	P1185	P2308	Q21070598	wikibase-item
# P1185-P2302-Q21503250-8bfd5a71-0	P1185	P2308	Q215627	wikibase-item
# P1185-P2302-Q21503250-8bfd5a71-0	P1185	P2308	Q95074	wikibase-item
# P1185-P2302-Q21503250-8bfd5a71-0	P1185	P2309	Q21503252	wikibase-item
# P1185-P2302-Q21503250-8bfd5a71-0	P1185	P2316	Q21502408	wikibase-item
# P1187-P2302-Q21503250-029277e1-0	P1187	P2308	Q15632617	wikibase-item
# P1187-P2302-Q21503250-029277e1-0	P1187	P2308	Q5	wikibase-item
# P1187-P2302-Q21503250-029277e1-0	P1187	P2309	Q21503252	wikibase-item
# P1188-P2302-Q21503250-bb0fc938-0	P1188	P2308	Q618123	wikibase-item
# P1188-P2302-Q21503250-bb0fc938-0	P1188	P2309	Q21503252	wikibase-item
# P119-P2302-Q21503250-c40bf16e-0	P119	P2308	Q16334295	wikibase-item
# P119-P2302-Q21503250-c40bf16e-0	P119	P2308	Q21070598	wikibase-item
# P119-P2302-Q21503250-c40bf16e-0	P119	P2308	Q36341	wikibase-item
# P119-P2302-Q21503250-c40bf16e-0	P119	P2308	Q5	wikibase-item
# P119-P2302-Q21503250-c40bf16e-0	P119	P2308	Q502931	wikibase-item
# P119-P2302-Q21503250-c40bf16e-0	P119	P2308	Q57812611	wikibase-item
# P119-P2302-Q21503250-c40bf16e-0	P119	P2308	Q622852	wikibase-item
# P119-P2302-Q21503250-c40bf16e-0	P119	P2308	Q95074	wikibase-item
# P119-P2302-Q21503250-c40bf16e-0	P119	P2309	Q21503252	wikibase-item
# P1191-P2302-Q21503250-85862ffc-0	P1191	P2308	Q17489659	wikibase-item
# P1191-P2302-Q21503250-85862ffc-0	P1191	P2308	Q26261757	wikibase-item
# P1191-P2302-Q21503250-85862ffc-0	P1191	P2308	Q386724	wikibase-item
# P1191-P2302-Q21503250-85862ffc-0	P1191	P2308	Q43099500	wikibase-item
# P1191-P2302-Q21503250-85862ffc-0	P1191	P2308	Q43100730	wikibase-item
# P1191-P2302-Q21503250-85862ffc-0	P1191	P2309	Q21503252	wikibase-item
# P1192-P2302-Q21503250-fc9e0e89-0	P1192	P2308	Q548662	wikibase-item
# P1192-P2302-Q21503250-fc9e0e89-0	P1192	P2309	Q21503252	wikibase-item
# P1193-P2302-Q21503250-ffb8fa39-0	P1193	P2308	Q7189713	wikibase-item
# P1193-P2302-Q21503250-ffb8fa39-0	P1193	P2309	Q21503252	wikibase-item
# P1194-P2302-Q21503250-e36cc341-0	P1194	P2308	Q2424752	wikibase-item
# P1194-P2302-Q21503250-e36cc341-0	P1194	P2309	Q21514624	wikibase-item
# P1195-P2302-Q21503250-1d7e0b98-0	P1195	P2308	Q235557	wikibase-item
# P1195-P2302-Q21503250-1d7e0b98-0	P1195	P2308	Q26085352	wikibase-item
# P1195-P2302-Q21503250-1d7e0b98-0	P1195	P2308	Q9143	wikibase-item
# P1195-P2302-Q21503250-1d7e0b98-0	P1195	P2309	Q21503252	wikibase-item
# P1196-P2302-Q21503250-149c05cf-0	P1196	P2308	Q14514600	wikibase-item
# P1196-P2302-Q21503250-149c05cf-0	P1196	P2308	Q16334298	wikibase-item
# P1196-P2302-Q21503250-149c05cf-0	P1196	P2308	Q21070598	wikibase-item
# P1196-P2302-Q21503250-149c05cf-0	P1196	P2308	Q215627	wikibase-item
# P1196-P2302-Q21503250-149c05cf-0	P1196	P2308	Q26401003	wikibase-item
# P1196-P2302-Q21503250-149c05cf-0	P1196	P2308	Q7239	wikibase-item
# P1196-P2302-Q21503250-149c05cf-0	P1196	P2308	Q95074	wikibase-item
# P1196-P2302-Q21503250-149c05cf-0	P1196	P2309	Q21503252	wikibase-item
# P1198-P2302-Q21503250-705ce4d4-0	P1198	P2308	Q1496967	wikibase-item
# P1198-P2302-Q21503250-705ce4d4-0	P1198	P2309	Q21503252	wikibase-item
# P1199-P2302-Q21503250-f49cecf6-0	P1199	P2308	Q1211967	wikibase-item
# P1199-P2302-Q21503250-f49cecf6-0	P1199	P2309	Q21514624	wikibase-item
# P1200-P2302-Q21503250-b51e8c2d-0	P1200	P2308	Q15324	wikibase-item
# P1200-P2302-Q21503250-b51e8c2d-0	P1200	P2309	Q21503252	wikibase-item
# P1200-P2302-Q21503250-b51e8c2d-0	P1200	P2316	Q21502408	wikibase-item
# P1201-P2302-Q21503250-90e09737-0	P1201	P2308	Q40218	wikibase-item
# P1201-P2302-Q21503250-90e09737-0	P1201	P2309	Q21503252	wikibase-item
# P1202-P2302-Q21503250-c5b3bbea-0	P1202	P2308	Q42889	wikibase-item
# P1202-P2302-Q21503250-c5b3bbea-0	P1202	P2309	Q21503252	wikibase-item
# P1203-P2302-Q21503250-5c5f41a2-0	P1203	P2308	Q856076	wikibase-item
# P1203-P2302-Q21503250-5c5f41a2-0	P1203	P2309	Q21503252	wikibase-item
# P1203-P2302-Q21503250-5c5f41a2-0	P1203	P2316	Q21502408	wikibase-item
# ...
# P918-P2302-Q21503250-1aa0cd78-0	P918	P2309	Q21514624	wikibase-item
# P918-P2302-Q21503250-7cfd7eae-0	P918	P2308	Q12737077	wikibase-item
# P918-P2302-Q21503250-7cfd7eae-0	P918	P2309	Q21503252	wikibase-item
# P919-P2302-Q21503250-0fbc6515-0	P919	P2308	Q12737077	wikibase-item
# P919-P2302-Q21503250-0fbc6515-0	P919	P2309	Q21503252	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q101965	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q12139612	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q1298668	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q1302249	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q131257	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q13406463	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q134995	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q1406161	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q14204246	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q151885	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q1656682	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q170584	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q17524420	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q178059	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q18593264	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q18812548	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q192909	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q1964968	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q21004260	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q21025364	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q21484471	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q230788	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q23649976	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q2416723	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q2668072	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q278485	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q2904148	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q305178	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q30612	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q3239681	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q362165	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q3689704	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q379833	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q386724	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q4503831	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q483394	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q4915012	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q5193377	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q600134	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q62090711	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q676586	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q9388534	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q955824	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q978	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2308	Q98144857	wikibase-item
# P921-P2302-Q21503250-7f671cff-0	P921	P2309	Q30208840	wikibase-item
# P922-P2302-Q21503250-500cfaa4-0	P922	P2308	Q11426	wikibase-item
# P922-P2302-Q21503250-500cfaa4-0	P922	P2309	Q21503252	wikibase-item
# P923-P2302-Q21503250-5fbeb7dd-0	P923	P2308	Q12136	wikibase-item
# P923-P2302-Q21503250-5fbeb7dd-0	P923	P2308	Q7189713	wikibase-item
# P923-P2302-Q21503250-5fbeb7dd-0	P923	P2309	Q21514624	wikibase-item
# P926-P2302-Q21503250-f575d1ad-0	P926	P2308	Q208467	wikibase-item
# P926-P2302-Q21503250-f575d1ad-0	P926	P2308	Q43054	wikibase-item
# P926-P2302-Q21503250-f575d1ad-0	P926	P2309	Q21514624	wikibase-item
# P927-P2302-Q21503250-be76d695-0	P927	P2308	Q27043950	wikibase-item
# P927-P2302-Q21503250-be76d695-0	P927	P2308	Q2996394	wikibase-item
# P927-P2302-Q21503250-be76d695-0	P927	P2309	Q30208840	wikibase-item
# P928-P2302-Q21503250-c08c6a0d-0	P928	P2308	Q43054	wikibase-item
# P928-P2302-Q21503250-c08c6a0d-0	P928	P2309	Q21514624	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q1067164	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q1210334	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q1311958	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q1414135	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q15141321	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q18199879	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q19832486	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q211382	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q22667	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q2516436	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q2678338	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q29048322	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q3491904	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q3565868	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q357685	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q5639	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q639030	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q728937	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q811704	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2308	Q870	wikibase-item
# P930-P2302-Q21503250-18c84820-0	P930	P2309	Q21503252	wikibase-item
# P931-P2302-Q21503250-c5b5ad4e-0	P931	P2308	Q376799	wikibase-item
# P931-P2302-Q21503250-c5b5ad4e-0	P931	P2309	Q21503252	wikibase-item
# P932-P2302-Q21503250-647ca973-0	P932	P2308	Q11826511	wikibase-item
# P932-P2302-Q21503250-647ca973-0	P932	P2308	Q191067	wikibase-item
# P932-P2302-Q21503250-647ca973-0	P932	P2308	Q637866	wikibase-item
# P932-P2302-Q21503250-647ca973-0	P932	P2309	Q21503252	wikibase-item
# P933-P2302-Q21503250-0d8b4cbd-0	P933	P2308	Q618123	wikibase-item
# P933-P2302-Q21503250-0d8b4cbd-0	P933	P2308	Q61961344	wikibase-item
# P933-P2302-Q21503250-0d8b4cbd-0	P933	P2308	Q8205328	wikibase-item
# P933-P2302-Q21503250-0d8b4cbd-0	P933	P2309	Q21503252	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q1047113	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q13002315	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q14514600	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q16334295	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q1747829	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q192581	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q21070568	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q28640	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q4164871	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q4271324	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q5	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2308	Q95074	wikibase-item
# P937-P2302-Q21503250-57a481f7-0	P937	P2309	Q21503252	wikibase-item
# P939-P2302-Q21503250-39fff21a-0	P939	P2308	Q2520520	wikibase-item
# P939-P2302-Q21503250-39fff21a-0	P939	P2309	Q21503252	wikibase-item
# P939-P2302-Q21503250-39fff21a-0	P939	P2316	Q21502408	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q101352	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q14623646	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q16391167	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q19791817	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q24334893	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q3895768	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q4164871	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q43229	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q5	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q618123	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q8436	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2308	Q95074	wikibase-item
# P94-P2302-Q21503250-6cc4ba73-0	P94	P2309	Q21503252	wikibase-item
# P941-P2302-Q21503250-49bb355b-0	P941	P2308	Q1190554	wikibase-item
# P941-P2302-Q21503250-49bb355b-0	P941	P2308	Q15709879	wikibase-item
# P941-P2302-Q21503250-49bb355b-0	P941	P2308	Q24334685	wikibase-item
# P941-P2302-Q21503250-49bb355b-0	P941	P2308	Q386724	wikibase-item
# P941-P2302-Q21503250-49bb355b-0	P941	P2308	Q483394	wikibase-item
# P941-P2302-Q21503250-49bb355b-0	P941	P2309	Q30208840	wikibase-item
# P942-P2302-Q21503250-bcd53b32-0	P942	P2308	Q1190554	wikibase-item
# P942-P2302-Q21503250-bcd53b32-0	P942	P2308	Q21070598	wikibase-item
# P942-P2302-Q21503250-bcd53b32-0	P942	P2308	Q2431196	wikibase-item
# P942-P2302-Q21503250-bcd53b32-0	P942	P2308	Q43229	wikibase-item
# P942-P2302-Q21503250-bcd53b32-0	P942	P2308	Q5	wikibase-item
# P942-P2302-Q21503250-bcd53b32-0	P942	P2308	Q95074	wikibase-item
# P942-P2302-Q21503250-bcd53b32-0	P942	P2309	Q21503252	wikibase-item
# P943-P2302-Q21503250-df639e85-0	P943	P2308	Q386724	wikibase-item
# P943-P2302-Q21503250-df639e85-0	P943	P2309	Q21503252	wikibase-item
# P944-P2302-Q21503250-a9f80ffd-0	P944	P2308	Q16521	wikibase-item
# P944-P2302-Q21503250-a9f80ffd-0	P944	P2309	Q21503252	wikibase-item
# P944-P2302-Q21503250-a9f80ffd-0	P944	P2316	Q21502408	wikibase-item
# P945-P2302-Q21503250-26716ed4-0	P945	P2308	Q14623646	wikibase-item
# P945-P2302-Q21503250-26716ed4-0	P945	P2308	Q43229	wikibase-item
# P945-P2302-Q21503250-26716ed4-0	P945	P2308	Q5	wikibase-item
# P945-P2302-Q21503250-26716ed4-0	P945	P2308	Q6857706	wikibase-item
# P945-P2302-Q21503250-26716ed4-0	P945	P2308	Q95074	wikibase-item
# P945-P2302-Q21503250-26716ed4-0	P945	P2309	Q21503252	wikibase-item
# P946-P2302-Q21503250-35f07c12-0	P946	P2308	Q167037	wikibase-item
# P946-P2302-Q21503250-35f07c12-0	P946	P2308	Q223371	wikibase-item
# P946-P2302-Q21503250-35f07c12-0	P946	P2308	Q431289	wikibase-item
# P946-P2302-Q21503250-35f07c12-0	P946	P2308	Q43229	wikibase-item
# P946-P2302-Q21503250-35f07c12-0	P946	P2308	Q4830453	wikibase-item
# P946-P2302-Q21503250-35f07c12-0	P946	P2309	Q21503252	wikibase-item
# P947-P2302-Q21503250-6a33b5ff-0	P947	P2308	Q5	wikibase-item
# P947-P2302-Q21503250-6a33b5ff-0	P947	P2309	Q21503252	wikibase-item
# P951-P2302-Q21503250-737f8488-0	P951	P2308	Q43229	wikibase-item
# P951-P2302-Q21503250-737f8488-0	P951	P2308	Q5	wikibase-item
# P951-P2302-Q21503250-737f8488-0	P951	P2309	Q21503252	wikibase-item
# P951-P2302-Q21503250-737f8488-0	P951	P2316	Q21502408	wikibase-item
# P952-P2302-Q21503250-e6404221-0	P952	P2308	Q12737077	wikibase-item
# P952-P2302-Q21503250-e6404221-0	P952	P2309	Q21503252	wikibase-item
# P953-P2302-Q21503250-f9122a2a-0	P953	P2308	Q1630279	wikibase-item
# P953-P2302-Q21503250-f9122a2a-0	P953	P2308	Q216200	wikibase-item
# P953-P2302-Q21503250-f9122a2a-0	P953	P2308	Q317623	wikibase-item
# P953-P2302-Q21503250-f9122a2a-0	P953	P2308	Q3331189	wikibase-item
# P953-P2302-Q21503250-f9122a2a-0	P953	P2308	Q386724	wikibase-item
# P953-P2302-Q21503250-f9122a2a-0	P953	P2309	Q21503252	wikibase-item
# P954-P2302-Q21503250-87f06bc1-0	P954	P2308	Q548662	wikibase-item
# P954-P2302-Q21503250-87f06bc1-0	P954	P2309	Q21503252	wikibase-item
# P957-P2302-Q21503250-4778df79-0	P957	P2308	Q187685	wikibase-item
# P957-P2302-Q21503250-4778df79-0	P957	P2308	Q3331189	wikibase-item
# P957-P2302-Q21503250-4778df79-0	P957	P2308	Q571	wikibase-item
# P957-P2302-Q21503250-4778df79-0	P957	P2309	Q21503252	wikibase-item
# P964-P2302-Q21503250-77469ac0-0	P964	P2308	Q261023	wikibase-item
# P964-P2302-Q21503250-77469ac0-0	P964	P2308	Q667509	wikibase-item
# P964-P2302-Q21503250-77469ac0-0	P964	P2309	Q21503252	wikibase-item
# P964-P2302-Q21503250-77469ac0-0	P964	P2316	Q21502408	wikibase-item
# P965-P2302-Q21503250-feb26b0d-0	P965	P2308	Q6023295	wikibase-item
# P965-P2302-Q21503250-feb26b0d-0	P965	P2309	Q21503252	wikibase-item
# P966-P2302-Q21503250-f5975015-0	P966	P2308	Q18127	wikibase-item
# P966-P2302-Q21503250-f5975015-0	P966	P2308	Q340169	wikibase-item
# P966-P2302-Q21503250-f5975015-0	P966	P2308	Q43229	wikibase-item
# P966-P2302-Q21503250-f5975015-0	P966	P2308	Q732577	wikibase-item
# P966-P2302-Q21503250-f5975015-0	P966	P2309	Q21503252	wikibase-item
# P967-P2302-Q21503250-51125652-0	P967	P2308	Q1190554	wikibase-item
# P967-P2302-Q21503250-51125652-0	P967	P2309	Q30208840	wikibase-item
# P967-P2302-Q21503250-51125652-0	P967	P2316	Q62026391	wikibase-item
# P968-P2302-Q21503250-fc9ec952-0	P968	P2308	Q132241	wikibase-item
# P968-P2302-Q21503250-fc9ec952-0	P968	P2308	Q13226383	wikibase-item
# P968-P2302-Q21503250-fc9ec952-0	P968	P2308	Q2221906	wikibase-item
# P968-P2302-Q21503250-fc9ec952-0	P968	P2308	Q43229	wikibase-item
# P968-P2302-Q21503250-fc9ec952-0	P968	P2308	Q5	wikibase-item
# P968-P2302-Q21503250-fc9ec952-0	P968	P2308	Q618779	wikibase-item
# P968-P2302-Q21503250-fc9ec952-0	P968	P2308	Q7397	wikibase-item
# P968-P2302-Q21503250-fc9ec952-0	P968	P2309	Q21503252	wikibase-item
# P97-P2302-Q21503250-8f64f593-0	P97	P2308	Q13002315	wikibase-item
# P97-P2302-Q21503250-8f64f593-0	P97	P2308	Q21070598	wikibase-item
# P97-P2302-Q21503250-8f64f593-0	P97	P2308	Q5	wikibase-item
# P97-P2302-Q21503250-8f64f593-0	P97	P2308	Q95074	wikibase-item
# P97-P2302-Q21503250-8f64f593-0	P97	P2309	Q21503252	wikibase-item
# P97-P2302-Q21503250-8f64f593-0	P97	P2316	Q21502408	wikibase-item
# P970-P2302-Q21503250-e4ca2760-0	P970	P2308	Q43054	wikibase-item
# P970-P2302-Q21503250-e4ca2760-0	P970	P2309	Q21514624	wikibase-item
# P971-P2302-Q21503250-e27d9234-0	P971	P2308	Q4167836	wikibase-item
# P971-P2302-Q21503250-e27d9234-0	P971	P2309	Q21503252	wikibase-item
# P971-P2302-Q21503250-e27d9234-0	P971	P2316	Q21502408	wikibase-item
# P974-P2302-Q21503250-6d5a5bcd-0	P974	P2308	Q16338046	wikibase-item
# P974-P2302-Q21503250-6d5a5bcd-0	P974	P2308	Q355304	wikibase-item
# P974-P2302-Q21503250-6d5a5bcd-0	P974	P2309	Q21503252	wikibase-item
# P98-P2302-Q21503250-271ffbe1-0	P98	P2308	Q1002697	wikibase-item
# P98-P2302-Q21503250-271ffbe1-0	P98	P2308	Q105420	wikibase-item
# P98-P2302-Q21503250-271ffbe1-0	P98	P2308	Q192283	wikibase-item
# P98-P2302-Q21503250-271ffbe1-0	P98	P2308	Q3331189	wikibase-item
# P98-P2302-Q21503250-271ffbe1-0	P98	P2308	Q386724	wikibase-item
# P98-P2302-Q21503250-271ffbe1-0	P98	P2308	Q41298	wikibase-item
# P98-P2302-Q21503250-271ffbe1-0	P98	P2309	Q21503252	wikibase-item
# P981-P2302-Q21503250-79998232-0	P981	P2308	Q486972	wikibase-item
# P981-P2302-Q21503250-79998232-0	P981	P2309	Q21503252	wikibase-item
# P982-P2302-Q21503250-e11160ed-0	P982	P2303	Q165	wikibase-item
# P982-P2302-Q21503250-e11160ed-0	P982	P2303	Q4169	wikibase-item
# P982-P2302-Q21503250-e11160ed-0	P982	P2308	Q23442	wikibase-item
# P982-P2302-Q21503250-e11160ed-0	P982	P2308	Q33837	wikibase-item
# P982-P2302-Q21503250-e11160ed-0	P982	P2308	Q486972	wikibase-item
# P982-P2302-Q21503250-e11160ed-0	P982	P2308	Q56061	wikibase-item
# P982-P2302-Q21503250-e11160ed-0	P982	P2308	Q6256	wikibase-item
# P982-P2302-Q21503250-e11160ed-0	P982	P2309	Q21503252	wikibase-item
# P984-P2302-Q21503250-edda09c0-0	P984	P2308	Q133156	wikibase-item
# P984-P2302-Q21503250-edda09c0-0	P984	P2308	Q26213387	wikibase-item
# P984-P2302-Q21503250-edda09c0-0	P984	P2308	Q47488809	wikibase-item
# P984-P2302-Q21503250-edda09c0-0	P984	P2308	Q6256	wikibase-item
# P984-P2302-Q21503250-edda09c0-0	P984	P2309	Q21503252	wikibase-item
# P988-P2302-Q21503250-735770c0-0	P988	P2308	Q1350310	wikibase-item
# P988-P2302-Q21503250-735770c0-0	P988	P2309	Q21503252	wikibase-item
# P988-P2302-Q21503250-735770c0-0	P988	P2316	Q21502408	wikibase-item
# P991-P2302-Q21503250-35f10096-0	P991	P2308	Q40231	wikibase-item
# P991-P2302-Q21503250-35f10096-0	P991	P2309	Q21503252	wikibase-item
# P996-P2302-Q21503250-e78f2bcd-0	P996	P2308	Q1238720	wikibase-item
# P996-P2302-Q21503250-e78f2bcd-0	P996	P2308	Q3331189	wikibase-item
# P996-P2302-Q21503250-e78f2bcd-0	P996	P2308	Q47461344	wikibase-item
# P996-P2302-Q21503250-e78f2bcd-0	P996	P2309	Q30208840	wikibase-item
# P999-P2302-Q21503250-e6abf0db-0	P999	P2308	Q523	wikibase-item
# P999-P2302-Q21503250-e6abf0db-0	P999	P2308	Q595871	wikibase-item
# P999-P2302-Q21503250-e6abf0db-0	P999	P2309	Q21503252	wikibase-item

# %%
df2[df2['node1']=='P840']
# Out:
#                                     id node1  label      node2  \
# 15111  P840-P2302-Q21503250-dab407fb-0  P840  P2303   Q6671108
# 15112  P840-P2302-Q21503250-dab407fb-0  P840  P2308   Q1185607
# 15113  P840-P2302-Q21503250-dab407fb-0  P840  P2308    Q386724
# 15114  P840-P2302-Q21503250-dab407fb-0  P840  P2309  Q21503252
#
#       node2;wikidatatype
# 15111      wikibase-item
# 15112      wikibase-item
# 15113      wikibase-item
# 15114      wikibase-item

# %% [markdown]
# # Check Constraint Violations for 5 random properties

# %%
# !kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.tsv.gz \
    --match "g: (node1)-[nodeProp:P840]->(node2)" \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P840.all.tsv \
    --graph-cache ~/sqlite3_caches/defg.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P840.all.tsv \
    ../../wikidata-20210215/derived.P31P279star.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), d: (node1)-[]->(par)" \
    --where 'par in ["Q1185607", "Q386724" or node1 = Q6671108' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(par) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P840.correct.tsv \
    --graph-cache ~/sqlite3_caches/defg.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P840.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P840.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P840.incorrect.tsv
# Out:
# [2021-03-08 12:20:08 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id", graph_1_c1."node1", graph_1_c1."label", graph_1_c1."node2"
#      FROM graph_1 AS graph_1_c1
#      WHERE graph_1_c1."label"=?
#   PARAS: ['P840']
# ---------------------------------------------
# Traceback (most recent call last):
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/cli/query.py", line 164, in run
#     query = kyquery.KgtkQuery(inputs, store, loglevel=loglevel,
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/kypher/query.py", line 178, in __init__
#     self.query = parser.intern(query)
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/kypher/parser.py", line 890, in intern
#     return KypherQuery(query_string)
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/kypher/parser.py", line 811, in __init__
#     self.query = intern_ast(self, self.parse.Kypher())
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/parsley.py", line 98, in invokeRule
#     raise err
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/ometa/runtime.py", line 554, in many
#     v, _ = fn()
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/kypher/grammar_compiled.py", line 4141, in _G_many_1411
#     _G_apply_1412, lastError = self._apply(self.rule_whitespace, "whitespace", [])
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/ometa/runtime.py", line 495, in _apply
#     [rule(), self.input])
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/kypher/grammar_compiled.py", line 4185, in rule_whitespace
#     _G_or_1425, lastError = self._or([_G_or_1417, _G_or_1419, _G_or_1421, _G_or_1423])
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/ometa/runtime.py", line 604, in _or
#     raise joinErrors(errors)
# ometa.runtime.ParseError:
#  MATCH m: (node1)-[nodeProp]->(node2), d: (node1)-[]->(par) WHERE par in ["Q1185607", "Q386724" or node1 = Q6671108 RETURN nodeProp.id, node1, nodeProp.label, node2, max(par) as `node1;ancestor`
#                                                                                                                     ^
# Parse error at line 1, column 116: expected one of ' ', '!=', '%', '(', '*', '+', ',', '-', '.', '/', '<', '<=', '<>', '=', '=~', '>', '>=', 'A', 'C', 'E', 'I', 'O', 'S', 'X', '[', '\n', '\t', ']', '^', 'a', 'c', 'e', 'i', 'o', 's', 'x', token '/*', or token '//'. trail: [Comment whitespace]
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/exceptions.py", line 46, in __call__
#     return_code = func(*args, **kwargs) or 0
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/cli/query.py", line 206, in run
#     raise KGTKException(str(e) + '\n')
# kgtk.exceptions.KGTKException:
#  MATCH m: (node1)-[nodeProp]->(node2), d: (node1)-[]->(par) WHERE par in ["Q1185607", "Q386724" or node1 = Q6671108 RETURN nodeProp.id, node1, nodeProp.label, node2, max(par) as `node1;ancestor`
#                                                                                                                     ^
# Parse error at line 1, column 116: expected one of ' ', '!=', '%', '(', '*', '+', ',', '-', '.', '/', '<', '<=', '<>', '=', '=~', '>', '>=', 'A', 'C', 'E', 'I', 'O', 'S', 'X', '[', '\n', '\t', ']', '^', 'a', 'c', 'e', 'i', 'o', 's', 'x', token '/*', or token '//'. trail: [Comment whitespace]
#
#
#
#  MATCH m: (node1)-[nodeProp]->(node2), d: (node1)-[]->(par) WHERE par in ["Q1185607", "Q386724" or node1 = Q6671108 RETURN nodeProp.id, node1, nodeProp.label, node2, max(par) as `node1;ancestor`
#                                                                                                                     ^
# Parse error at line 1, column 116: expected one of ' ', '!=', '%', '(', '*', '+', ',', '-', '.', '/', '<', '<=', '<>', '=', '=~', '>', '>=', 'A', 'C', 'E', 'I', 'O', 'S', 'X', '[', '\n', '\t', ']', '^', 'a', 'c', 'e', 'i', 'o', 's', 'x', token '/*', or token '//'. trail: [Comment whitespace]
#
#
# Traceback (most recent call last):
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/io/kgtkreader.py", line 779, in _build_column_names
#     header: str = next(source).rstrip("\r\n")
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/utils/closableiter.py", line 30, in __next__
#     return self.s.__next__()
# StopIteration
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/cli/ifnotexists.py", line 257, in run
#     ie.process()
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/iff/kgtkifexists.py", line 768, in process
#     filter_kr: KgtkReader = KgtkReader.open(self.filter_file_path,
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/io/kgtkreader.py", line 540, in open
#     (header, column_names) = cls._build_column_names(source, options, error_file=error_file, verbose=verbose)
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/io/kgtkreader.py", line 781, in _build_column_names
#     raise ValueError("No header line in file")
# ValueError: No header line in file
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/exceptions.py", line 46, in __call__
#     return_code = func(*args, **kwargs) or 0
#   File "/nas/home/kshenoy/miniconda3/lib/python3.8/site-packages/kgtk/cli/ifnotexists.py", line 264, in run
#     raise KGTKException(str(e))
# kgtk.exceptions.KGTKException: No header line in file
# No header line in file

# %%
# !wc -l ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P840*
# Out:
#   77935 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P840.all.tsv
#       0 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P840.correct.tsv
#   77935 total

# %%
# !kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.tsv.gz \
    --match "g: (node1)-[nodeProp:P734]->(node2)" \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734.all.tsv \
    --graph-cache ~/sqlite3_caches/defg.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734.all.tsv \
    ../../wikidata-20210215/derived.P31P279star.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), d: (node1)-[]->(par)" \
    --where 'par in ["Q13417114","Q1517820", "Q15331236", "Q16979650", "Q201662", "Q21070598", "Q211503", "Q215627", "Q5", "Q62792750", "Q8436", "Q95074"]' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(par) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734.correct.tsv \
    --graph-cache ~/sqlite3_caches/defg.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734.incorrect.tsv
# Out:
# [2021-03-08 12:29:53 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id", graph_1_c1."node1", graph_1_c1."label", graph_1_c1."node2"
#      FROM graph_1 AS graph_1_c1
#      WHERE graph_1_c1."label"=?
#   PARAS: ['P734']
# ---------------------------------------------
# [2021-03-08 12:58:16 sqlstore]: IMPORT graph directly into table graph_10 from /data/wd-correctness/constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734.all.tsv ...
# [2021-03-08 12:58:20 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_10_c1."id", graph_10_c1."node1", graph_10_c1."label", graph_10_c1."node2", max(graph_7_c2."node2") "_aLias.node1;ancestor"
#      FROM graph_10 AS graph_10_c1, graph_7 AS graph_7_c2
#      WHERE graph_10_c1."node1"=graph_7_c2."node1"
#      AND (graph_7_c2."node2" IN (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?))
#      GROUP BY graph_10_c1."id", graph_10_c1."node1", graph_10_c1."label", graph_10_c1."node2"
#   PARAS: ['Q13417114', 'Q1517820', 'Q15331236', 'Q16979650', 'Q201662', 'Q21070598', 'Q211503', 'Q215627', 'Q5', 'Q62792750', 'Q8436', 'Q95074']
# ---------------------------------------------
# [2021-03-08 12:58:20 sqlstore]: CREATE INDEX on table graph_10 column node1 ...
# [2021-03-08 12:58:22 sqlstore]: ANALYZE INDEX on table graph_10 column node1 ...

# %%
# !wc -l ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734*
# Out:
#   2705975 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734.all.tsv
#   2703740 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734.correct.tsv
#      2236 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P734.incorrect.tsv
#   5411951 total

# %%
# !kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.tsv.gz \
    --match "g: (node1)-[nodeProp:P495]->(node2)" \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495.all.tsv \
    --graph-cache ~/sqlite3_caches/defg.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495.all.tsv \
    ../../wikidata-20210215/derived.isastar.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), d: (node1)-[]->(par)" \
    --where 'par in ["Q15401930", "Q1778821", "Q187931", "Q2088357", "Q2095", "Q2531956", "Q28820001", "Q38829", "Q5256141", "Q84310035", "Q968159"]' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(par) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495.correct.tsv \
    --graph-cache ~/sqlite3_caches/defg.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495.incorrect.tsv
# Out:
# [2021-03-08 14:01:15 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id", graph_1_c1."node1", graph_1_c1."label", graph_1_c1."node2"
#      FROM graph_1 AS graph_1_c1
#      WHERE graph_1_c1."label"=?
#   PARAS: ['P495']
# ---------------------------------------------
# [2021-03-08 14:22:45 sqlstore]: IMPORT graph directly into table graph_11 from /data/wd-correctness/constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495.all.tsv ...
# [2021-03-08 14:22:47 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_11_c1."id", graph_11_c1."node1", graph_11_c1."label", graph_11_c1."node2", max(graph_3_c2."node2") "_aLias.node1;ancestor"
#      FROM graph_11 AS graph_11_c1, graph_3 AS graph_3_c2
#      WHERE graph_11_c1."node1"=graph_3_c2."node1"
#      AND (graph_3_c2."node2" IN (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?))
#      GROUP BY graph_11_c1."id", graph_11_c1."node1", graph_11_c1."label", graph_11_c1."node2"
#   PARAS: ['Q15401930', 'Q1778821', 'Q187931', 'Q2088357', 'Q2095', 'Q2531956', 'Q28820001', 'Q38829', 'Q5256141', 'Q84310035', 'Q968159']
# ---------------------------------------------
# [2021-03-08 14:22:47 sqlstore]: CREATE INDEX on table graph_11 column node1 ...
# [2021-03-08 14:22:48 sqlstore]: ANALYZE INDEX on table graph_11 column node1 ...

# %%
# !wc -l ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495*
# Out:
#   1112551 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495.all.tsv
#   1081879 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495.correct.tsv
#     30673 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P495.incorrect.tsv
#   2225103 total

# %%
# !kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.tsv.gz \
    --match "g: (node1)-[nodeProp:P136]->(node2)" \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136.all.tsv \
    --graph-cache ~/sqlite3_caches/defg.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136.all.tsv \
    ../../wikidata-20210215/derived.isastar.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), d: (node1)-[]->(par)" \
    --where 'par in ["Q1047299", "Q10648343", "Q11410", "Q1141470", "Q11424", "Q12737077", "Q15116915", "Q15416", "Q16334295", "Q16686448", "Q17489659", "Q18127", "Q2088357", "Q215380", "Q28640", "Q378427", "Q386724", "Q476300", "Q5", "Q5519943","Q742421"]' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(par) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136.correct.tsv \
    --graph-cache ~/sqlite3_caches/defg.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136.incorrect.tsv
# Out:
# [2021-03-08 15:06:49 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id", graph_1_c1."node1", graph_1_c1."label", graph_1_c1."node2"
#      FROM graph_1 AS graph_1_c1
#      WHERE graph_1_c1."label"=?
#   PARAS: ['P136']
# ---------------------------------------------
# [2021-03-08 15:34:35 sqlstore]: IMPORT graph directly into table graph_12 from /data/wd-correctness/constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136.all.tsv ...
# [2021-03-08 15:34:37 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_12_c1."id", graph_3_c2."node1", graph_12_c1."label", graph_12_c1."node2", max(graph_3_c2."node2") "_aLias.node1;ancestor"
#      FROM graph_12 AS graph_12_c1, graph_3 AS graph_3_c2
#      WHERE graph_12_c1."node1"=graph_3_c2."node1"
#      AND (graph_3_c2."node2" IN (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?))
#      GROUP BY graph_12_c1."id", graph_3_c2."node1", graph_12_c1."label", graph_12_c1."node2"
#   PARAS: ['Q1047299', 'Q10648343', 'Q11410', 'Q1141470', 'Q11424', 'Q12737077', 'Q15116915', 'Q15416', 'Q16334295', 'Q16686448', 'Q17489659', 'Q18127', 'Q2088357', 'Q215380', 'Q28640', 'Q378427', 'Q386724', 'Q476300', 'Q5', 'Q5519943', 'Q742421']
# ---------------------------------------------
# [2021-03-08 15:34:37 sqlstore]: CREATE INDEX on table graph_12 column node1 ...
# [2021-03-08 15:34:38 sqlstore]: ANALYZE INDEX on table graph_12 column node1 ...

# %%
# !wc -l ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136*
# Out:
#   1334007 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136.all.tsv
#   1329307 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136.correct.tsv
#      4701 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P136.incorrect.tsv
#   2668015 total

# %%
# !kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.tsv.gz \
    --match "g: (node1)-[nodeProp:P1811]->(node2)" \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811.all.tsv \
    --graph-cache ~/sqlite3_caches/defg.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811.all.tsv \
    ../../wikidata-20210215/derived.P31P279star.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), d: (node1)-[]->(par)" \
    --where 'par in ["Q2431196"]' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(par) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811.correct.tsv \
    --graph-cache ~/sqlite3_caches/defg.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811.incorrect.tsv
# Out:
# [2021-03-08 00:32:23 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id", graph_1_c1."node1", graph_1_c1."label", graph_1_c1."node2"
#      FROM graph_1 AS graph_1_c1
#      WHERE graph_1_c1."label"=?
#   PARAS: ['P1811']
# ---------------------------------------------
# [2021-03-08 00:34:22 sqlstore]: IMPORT graph directly into table graph_9 from /data/wd-correctness/constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811.all.tsv ...
# [2021-03-08 00:34:23 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_9_c1."id", graph_7_c2."node1", graph_9_c1."label", graph_9_c1."node2", max(graph_7_c2."node2") "_aLias.node1;ancestor"
#      FROM graph_7 AS graph_7_c2, graph_9 AS graph_9_c1
#      WHERE graph_7_c2."node1"=graph_9_c1."node1"
#      AND (graph_7_c2."node2" IN (?))
#      GROUP BY graph_9_c1."id", graph_7_c2."node1", graph_9_c1."label", graph_9_c1."node2"
#   PARAS: ['Q2431196']
# ---------------------------------------------
# [2021-03-08 00:34:23 sqlstore]: CREATE INDEX on table graph_9 column node1 ...
# [2021-03-08 00:34:23 sqlstore]: ANALYZE INDEX on table graph_9 column node1 ...

# %%
# !wc -l ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811*
# Out:
#   4334 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811.all.tsv
#   4302 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811.correct.tsv
#     33 ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.P1811.incorrect.tsv
#   8669 total

# %% [markdown]
# ## Mandatory Constraints

# %%
# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.tsv.gz \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match "t: (node1)-[nodeProp:P988]->(node2), c: (rLabel)-[:P2309]->(relConstVal), c: (rLabel)-[:P2316]->(typeConstVal)" \
    --where 'nodeProp.label = rLabel and relConstVal = "Q21503252" and typeConstVal = "Q21502408"' \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.all.tsv \
    --graph-cache ~/sqlite3_caches/mandConst001.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../wikidata-20210215/derived.P31P279star.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2308]->(parent), d: (node1)-[]->(par), c: (eLabel)-[:P2303]->(eNode)" \
    --where 'nodeProp.label = rLabel and (par = parent or (rLabel = eLabel and node1 = eNode))' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.correct.tsv \
    --graph-cache ~/sqlite3_caches/mandConst001.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.incorrect.tsv
# Out:
# [2021-03-04 17:33:47 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id", graph_1_c1."node1", graph_1_c1."label", graph_1_c1."node2"
#      FROM graph_1 AS graph_1_c1, graph_2 AS graph_2_c2, graph_2 AS graph_2_c3
#      WHERE graph_2_c2."label"=?
#      AND graph_2_c3."label"=?
#      AND graph_2_c2."node1"=graph_2_c3."node1"
#      AND ((graph_1_c1."label" = graph_2_c3."node1") AND ((graph_2_c2."node2" = ?) AND (graph_2_c3."node2" = ?)))
#   PARAS: ['P2309', 'P2316', 'Q21503252', 'Q21502408']
# ---------------------------------------------
# [2021-03-04 17:33:47 sqlstore]: CREATE INDEX on table graph_2 column node1 ...
# [2021-03-04 17:33:47 sqlstore]: ANALYZE INDEX on table graph_2 column node1 ...
# [2021-03-04 17:33:47 sqlstore]: CREATE INDEX on table graph_2 column label ...
# [2021-03-04 17:33:47 sqlstore]: ANALYZE INDEX on table graph_2 column label ...
# [2021-03-04 17:33:49 sqlstore]: IMPORT graph directly into table graph_3 from /data/wd-correctness/constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceOf.all.tsv ...
# [2021-03-04 17:33:49 sqlstore]: IMPORT graph directly into table graph_4 from /data/wd-correctness/wikidata-20210215/derived.P31P279star.tsv.gz ...
# ^C

# %%
# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims_truncated.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match "t: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2309]->(relConstVal), c: (rLabel)-[:P2316]->(typeConstVal)" \
    --where 'nodeProp.label = rLabel and relConstVal = "Q21514624" and typeConstVal = "Q21502408"' \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.all.tsv \
    --graph-cache ~/sqlite3_caches/mandConst002.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../wikidata-20210215/derived.P279star.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2308]->(parent), d: (node1)-[]->(par), c: (eLabel)-[:P2303]->(eNode)" \
    --where 'nodeProp.label = rLabel and (par = parent or (rLabel = eLabel and node1 = eNode))' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.correct.tsv \
    --graph-cache ~/sqlite3_caches/mandConst002.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.incorrect.tsv

# %%
# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims_truncated.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match "t: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2309]->(relConstVal), c: (rLabel)-[:P2316]->(typeConstVal)" \
    --where 'nodeProp.label = rLabel and relConstVal = "Q30208840" and typeConstVal = "Q21502408"' \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.all.tsv \
    --graph-cache ~/sqlite3_caches/mandConst3.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../wikidata-20210215/derived.isastar.tsv.gz  \
    --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2308]->(parent), d: (node1)-[]->(par), c: (eLabel)-[:P2303]->(eNode)" \
    --where 'nodeProp.label = rLabel and (par = parent or (rLabel = eLabel and node1 = eNode))' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.correct.tsv \
    --graph-cache ~/sqlite3_caches/mandConst3.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.incorrect.tsv

# %% [markdown]
# ## Suggestion Constraints

# %%
# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims_truncated.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match "t: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2309]->(relConstVal), c: (rLabel)-[:P2316]->(typeConstVal)" \
    --where 'nodeProp.label = rLabel and relConstVal = "Q21503252" and typeConstVal = "Q62026391"' \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.suggestion.instanceOf.all.tsv \
    --graph-cache ~/sqlite3_caches/mandConst11.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.suggestion.instanceOf.all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../wikidata-20210215/derived.P31P279star.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2308]->(parent), d: (node1)-[]->(par), c: (eLabel)-[:P2303]->(eNode)" \
    --where 'nodeProp.label = rLabel and (par = parent or (rLabel = eLabel and node1 = eNode))' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.suggestion.instanceOf.correct.tsv \
    --graph-cache ~/sqlite3_caches/mandConst11.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.suggestion.instanceOf.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.suggestion.instanceOf.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.suggestion.instanceOf.incorrect.tsv

# %%
# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims_truncated.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match "t: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2309]->(relConstVal), c: (rLabel)-[:P2316]->(typeConstVal)" \
    --where 'nodeProp.label = rLabel and relConstVal = "Q21514624" and typeConstVal = "Q62026391"' \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.all.tsv \
    --graph-cache ~/sqlite3_caches/mandConst21.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../wikidata-20210215/derived.P279star.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2308]->(parent), d: (node1)-[]->(par), c: (eLabel)-[:P2303]->(eNode)" \
    --where 'nodeProp.label = rLabel and (par = parent or (rLabel = eLabel and node1 = eNode))' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.correct.tsv \
    --graph-cache ~/sqlite3_caches/mandConst21.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.subclass.incorrect.tsv

# %%
# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims_truncated.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    --match "t: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2309]->(relConstVal), c: (rLabel)-[:P2316]->(typeConstVal)" \
    --where 'nodeProp.label = rLabel and relConstVal = "Q30208840" and typeConstVal = "Q62026391"' \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.all.tsv \
    --graph-cache ~/sqlite3_caches/mandConst33.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../wikidata-20210215/derived.isastar.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2308]->(parent), d: (node1)-[]->(par), c: (eLabel)-[:P2303]->(eNode)" \
    --where 'nodeProp.label = rLabel and (par = parent or (rLabel = eLabel and node1 = eNode))' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.correct.tsv \
    --graph-cache ~/sqlite3_caches/mandConst34.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.mandatory.instanceofOrsubclass.incorrect.tsv

# %% [markdown]
# ## Normal Constraints

# %%
# !kgtk ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints_relation.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug_normalConst.tsv

# %%
# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims_truncated.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug_normalConst.tsv \
    --match "t: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2309]->(relConstVal), m: (rLabel)-[:P2309]->()" \
    --where 'nodeProp.label = rLabel and relConstVal = "Q21503252"' \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceOf.all.tsv \
    --graph-cache ~/sqlite3_caches/mandConst1.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceOf.all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../wikidata-20210215/derived.P31P279star.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2308]->(parent), d: (node1)-[]->(par), c: (eLabel)-[:P2303]->(eNode)" \
    --where 'nodeProp.label = rLabel and (par = parent or (rLabel = eLabel and node1 = eNode))' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceOf.correct.tsv \
    --graph-cache ~/sqlite3_caches/mandConst1.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceOf.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceOf.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceOf.incorrect.tsv

# %%
# !kgtk --debug query -i ../../constraintsOP/typeConstraint/claims_truncated.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug_normalConst.tsv \
    --match "t: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2309]->(relConstVal), m: (rLabel)-[:P2309]->()" \
    --where 'nodeProp.label = rLabel and relConstVal = "Q21514624"' \
    --return 'nodeProp.id, node1, nodeProp.label, node2' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.subclass.all.tsv \
    --graph-cache ~/sqlite3_caches/mandConst1.sqlite3.db ; \
 kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.normal.subclass.all.tsv \
    ../../constraintsOP/typeConstraint/claims.type-constraints_all.tsv \
    ../../wikidata-20210215/derived.P31P279star.tsv.gz \
    --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[:P2308]->(parent), d: (node1)-[]->(par), c: (eLabel)-[:P2303]->(eNode)" \
    --where 'nodeProp.label = rLabel and (par = parent or (rLabel = eLabel and node1 = eNode))' \
    --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.subclass.correct.tsv \
    --graph-cache ~/sqlite3_caches/mandConst1.sqlite3.db ; \
 kgtk --debug ifnotexists -i ../../constraintsOP/typeConstraint/claims.type-constraints.normal.subclass.all.tsv \
    --filter-on ../../constraintsOP/typeConstraint/claims.type-constraints.normal.subclass.correct.tsv \
    --filter-mode NONE \
    --input-keys node1 label \
    --filter-keys node1 label \
    -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.subclass.incorrect.tsv

# %%
# !screen -dm kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.string.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_relation.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug_normalConst.tsv \
#     --match "g: (node1)-[nodeProp]->(node2), r: (rLabel)-[]->(relConstVal), m: (rLabel)-[]->()" \
#     --where 'nodeProp.label = rLabel and relConstVal = "Q21503252"' \
#     --return 'nodeProp.id, node1, nodeProp.label, node2' \
#     -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceOf.all.tsv \
#     --graph-cache ~/sqlite3_caches/temp131.sqlite3.db
# !screen -dm kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.string.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_relation.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug_normalConst.tsv \
#     --match "g: (node1)-[nodeProp]->(node2), r: (rLabel)-[]->(relConstVal), m: (rLabel)-[]->()" \
#     --where 'nodeProp.label = rLabel and relConstVal = "Q21514624"' \
#     --return 'nodeProp.id, node1, nodeProp.label, node2' \
#     -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.subclass.all.tsv \
#     --graph-cache ~/sqlite3_caches/temp132.sqlite3.db
# !screen -dm kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.string.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_relation.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug_normalConst.tsv \
#     --match "g: (node1)-[nodeProp]->(node2), r: (rLabel)-[]->(relConstVal), m: (rLabel)-[]->()" \
#     --where 'nodeProp.label = rLabel and relConstVal = "Q30208840"' \
#     --return 'nodeProp.id, node1, nodeProp.label, node2' \
#     -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceofOrsubclass.all.tsv \
#     --graph-cache ~/sqlite3_caches/temp133.sqlite3.db

# %% [markdown]
# #### Correct

# %%
# !screen -dm kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceOf.all.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_classes.tsv \
#     ../../wikidata-20210215/derived.P31P279star.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_exceptions_diff_way.tsv \
#     --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[]->(parent), d: (node1)-[]->(par), e: (rLabel)-[]->(eNode)" \
#     --where 'nodeProp.label = rLabel and (par = parent or node1 = eNode)' \
#     --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
#     -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceOf.correct.tsv \
#     --graph-cache ~/sqlite3_caches/temp131.sqlite3.db
# !screen -dm kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.normal.subclass.all.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_classes.tsv \
#     ../../wikidata-20210215/derived.P31P279star.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_exceptions_diff_way.tsv \
#     --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[]->(parent), d: (node1)-[]->(par), e: (rLabel)-[]->(eNode)" \
#     --where 'nodeProp.label = rLabel and (par = parent or node1 = eNode)' \
#     --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
#     -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.subclass.correct.tsv \
#     --graph-cache ~/sqlite3_caches/temp132.sqlite3.db
# !screen -dm kgtk --debug query -i ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceofOrsubclass.all.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_classes.tsv \
#     ../../wikidata-20210215/derived.P31P279star.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_exceptions_diff_way.tsv \
#     --match "m: (node1)-[nodeProp]->(node2), c: (rLabel)-[]->(parent), d: (node1)-[]->(par), e: (rLabel)-[]->(eNode)" \
#     --where 'nodeProp.label = rLabel and (par = parent or node1 = eNode)' \
#     --return 'nodeProp.id, node1, nodeProp.label, node2, max(parent) as `node1;ancestor`' \
#     -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceofOrsubclass.correct.tsv \
#     --graph-cache ~/sqlite3_caches/temp133.sqlite3.db

# %% [markdown]
# #### Incorrect

# %%
# !screen -dm kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.string.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_relation.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug_normalConst.tsv \
#     ../../constraintsOP/typeConstraint/claimsa.type-constraints_classes.tsv \
#     ../../wikidata-20210215/derived.P31P279star.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_exceptions_diff_way.tsv \
#     --match "g: (node1)-[nodeProp]->(node2), r: (rLabel)-[]->(relConstVal), m: (rLabel)-[]->(), c: (rLabel)-[]->(parent), d: (node1)-[]->(par), e: (rLabel)-[]->(eNode)" \
#     --where 'nodeProp.label = rLabel and relConstVal = "Q21503252" and par != parent and node1 != eNode' \
#     --return 'nodeProp.id, node1, nodeProp.label, node2, par as `node1;ancestor`' \
#     -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceOf.incorrect.tsv \
#     --graph-cache ~/sqlite3_caches/temp131a.sqlite3.db
# !screen -dm kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.string.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_relation.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug_normalConst.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_classes.tsv \
#     ../../wikidata-20210215/derived.P279star.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_exceptions_diff_way.tsv \
#     --match "g: (node1)-[nodeProp]->(node2), r: (rLabel)-[]->(relConstVal), m: (rLabel)-[]->(), c: (rLabel)-[]->(parent), d: (node1)-[]->(par), e: (rLabel)-[]->(eNode)" \
#     --where 'nodeProp.label = rLabel and relConstVal = "Q21514624" and par != parent and node1 != eNode' \
#     --return 'nodeProp.id, node1, nodeProp.label, node2, par as `node1;ancestor`' \
#     -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.subclass.incorrect.tsv \
#     --graph-cache ~/sqlite3_caches/temp132a.sqlite3.db
# !screen -dm kgtk --debug query -i ../../gdrive-kgtk-dump-2020-12-07/claims.string.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_relation.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_mandSug_normalConst.tsv \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_classes.tsv \
#     ../../wikidata-20210215/derived.isastar.tsv.gz \
#     ../../constraintsOP/typeConstraint/claims.type-constraints_exceptions_diff_way.tsv \
#     --match "g: (node1)-[nodeProp]->(node2), r: (rLabel)-[]->(relConstVal), m: (rLabel)-[]->(), c: (rLabel)-[]->(parent), d: (node1)-[]->(par), e: (rLabel)-[]->(eNode)" \
#     --where 'nodeProp.label = rLabel and relConstVal = "Q30208840" and par != parent and node1 != eNode' \
#     --return 'nodeProp.id, node1, nodeProp.label, node2, par as `node1;ancestor`' \
#     -o ../../constraintsOP/typeConstraint/claims.type-constraints.normal.instanceofOrsubclass.incorrect.tsv \
#     --graph-cache ~/sqlite3_caches/temp133a.sqlite3.db
